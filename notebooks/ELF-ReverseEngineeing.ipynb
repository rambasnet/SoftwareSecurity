# %% [markdown]
# # Binary and Reverse Engineering
# - reverse engineering of binary program is a popular skill in malware analysis
# - as most malware programs are binary writtern in C/C++ programming languages, they needed to be reverse engineered to understand the functinalities of malware under the hood
#
# ## Executable and Linkable Format (ELF)
# - https://en.wikipedia.org/wiki/Executable_and_Linkable_Format
# - common format for executables files, object code, shared libraries, and core dumps
# ![ELF](./media/ELF.png)
# - an ELF file has two views: the program header shows the segments used at run time, whereas the section header lists the set of sections of the binary.
# - let's compile hello.cpp program provided in demos folder and examine ELF format using various tools and commands

# %%
! cat ../demos/hello.cpp

# %%
! cat ../demos/hello.c

# %%
! g++ -m32 -o hello.exe ../demos/hello.cpp

# %%
! gcc -m32 -o hello_c.exe ../demos/hello.c

# %%
! g++ -m32 -o memory_segments.exe ../demos/memory_segments.cpp

# %%
! ./hello.exe

# %%
! ./hello_c.exe

# %%
! ls -al hello.exe

# %%
! ls -al hello_c.exe

# %%
! cat hello.exe

# %%
! cat hello_c.exe

# %% [markdown]
# ## file utility
# - displays some information about ELF files

# %%
! file ../demos/hello.cpp
# Out:
# ../demos/hello.cpp: C++ source, ASCII text

# %%
! file ../demos/hello.c
# Out:
# ../demos/hello.c: C source, ASCII text

# %%
! file hello.exe
# Out:
# hello.exe: ELF 32-bit LSB pie executable, Intel 80386, version 1 (SYSV), dynamically linked, interpreter /lib/ld-linux.so.2, BuildID[sha1]=8b33472863baba15aba327716ea002fcdb58fb39, for GNU/Linux 3.2.0, not stripped

# %%
! file hello_c.exe
# Out:
# hello_c.exe: ELF 32-bit LSB pie executable, Intel 80386, version 1 (SYSV), dynamically linked, interpreter /lib/ld-linux.so.2, BuildID[sha1]=0ecfcf2ec259106a7a93642771efb3c5fd26913d, for GNU/Linux 3.2.0, not stripped

# %%
# display hex and ASCII in two columns
! hexdump -C hello.exe
# Out:
# 00000000  7f 45 4c 46 01 01 01 00  00 00 00 00 00 00 00 00  |.ELF............|
# 00000010  03 00 03 00 01 00 00 00  70 10 00 00 34 00 00 00  |........p...4...|
# 00000020  9c 37 00 00 00 00 00 00  34 00 20 00 0b 00 28 00  |.7......4. ...(.|
# 00000030  1e 00 1d 00 06 00 00 00  34 00 00 00 34 00 00 00  |........4...4...|
# 00000040  34 00 00 00 60 01 00 00  60 01 00 00 04 00 00 00  |4...`...`.......|
# 00000050  04 00 00 00 03 00 00 00  94 01 00 00 94 01 00 00  |................|
# 00000060  94 01 00 00 13 00 00 00  13 00 00 00 04 00 00 00  |................|
# 00000070  01 00 00 00 01 00 00 00  00 00 00 00 00 00 00 00  |................|
# 00000080  00 00 00 00 18 05 00 00  18 05 00 00 04 00 00 00  |................|
# 00000090  00 10 00 00 01 00 00 00  00 10 00 00 00 10 00 00  |................|
# 000000a0  00 10 00 00 08 02 00 00  08 02 00 00 05 00 00 00  |................|
# 000000b0  00 10 00 00 01 00 00 00  00 20 00 00 00 20 00 00  |......... ... ..|
# 000000c0  00 20 00 00 f8 00 00 00  f8 00 00 00 04 00 00 00  |. ..............|
# 000000d0  00 10 00 00 01 00 00 00  d8 2e 00 00 d8 3e 00 00  |.............>..|
# 000002d0  6d 6f 6e 5f 73 74 61 72  74 5f 5f 00 5f 49 54 4d  |mon_start__._ITM|
# 000002e0  5f 64 65 72 65 67 69 73  74 65 72 54 4d 43 6c 6f  |_deregisterTMClo|
# 000002f0  6e 65 54 61 62 6c 65 00  5f 49 54 4d 5f 72 65 67  |neTable._ITM_reg|
# 00000300  69 73 74 65 72 54 4d 43  6c 6f 6e 65 54 61 62 6c  |isterTMCloneTabl|
# 00000310  65 00 5f 5a 53 74 34 65  6e 64 6c 49 63 53 74 31  |e._ZSt4endlIcSt1|
# 00000320  31 63 68 61 72 5f 74 72  61 69 74 73 49 63 45 45  |1char_traitsIcEE|
# 00000330  52 53 74 31 33 62 61 73  69 63 5f 6f 73 74 72 65  |RSt13basic_ostre|
# 00000340  61 6d 49 54 5f 54 30 5f  45 53 36 5f 00 5f 5a 4e  |amIT_T0_ES6_._ZN|
# 00000350  53 6f 6c 73 45 50 46 52  53 6f 53 5f 45 00 5f 5a  |SolsEPFRSoS_E._Z|
# 00000360  53 74 32 31 69 6f 73 5f  62 61 73 65 5f 6c 69 62  |St21ios_base_lib|
# 00000370  72 61 72 79 5f 69 6e 69  74 76 00 5f 5a 53 74 6c  |rary_initv._ZStl|
# 00000380  73 49 53 74 31 31 63 68  61 72 5f 74 72 61 69 74  |sISt11char_trait|
# 00000390  73 49 63 45 45 52 53 74  31 33 62 61 73 69 63 5f  |sIcEERSt13basic_|
# 000003a0  6f 73 74 72 65 61 6d 49  63 54 5f 45 53 35 5f 50  |ostreamIcT_ES5_P|
# 000003b0  4b 63 00 5f 5a 53 74 34  63 6f 75 74 00 5f 49 4f  |Kc._ZSt4cout._IO|
# 000003c0  5f 73 74 64 69 6e 5f 75  73 65 64 00 5f 5f 6c 69  |_stdin_used.__li|
# 000003d0  62 63 5f 73 74 61 72 74  5f 6d 61 69 6e 00 5f 5f  |bc_start_main.__|
# 000003e0  63 78 61 5f 66 69 6e 61  6c 69 7a 65 00 6c 69 62  |cxa_finalize.lib|
# 000003f0  73 74 64 63 2b 2b 2e 73  6f 2e 36 00 6c 69 62 63  |stdc++.so.6.libc|
# 00000400  2e 73 6f 2e 36 00 47 4c  49 42 43 58 58 5f 33 2e  |.so.6.GLIBCXX_3.|
# 00000410  34 2e 33 32 00 47 4c 49  42 43 58 58 5f 33 2e 34  |4.32.GLIBCXX_3.4|
# 00000420  00 47 4c 49 42 43 5f 32  2e 33 34 00 47 4c 49 42  |.GLIBC_2.34.GLIB|
# 00000430  43 5f 32 2e 31 2e 33 00  00 00 02 00 03 00 04 00  |C_2.1.3.........|
# 00000440  03 00 03 00 03 00 05 00  01 00 01 00 01 00 01 00  |................|
# 00000450  01 00 02 00 21 01 00 00  10 00 00 00 30 00 00 00  |....!.......0...|
# 00000460  42 f8 97 02 00 00 05 00  3a 01 00 00 10 00 00 00  |B.......:.......|
# 00000470  74 29 92 08 00 00 03 00  49 01 00 00 00 00 00 00  |t)......I.......|
# 00000480  01 00 02 00 30 01 00 00  10 00 00 00 00 00 00 00  |....0...........|
# 00003340  63 6c 6f 6e 65 73 00 5f  5f 64 6f 5f 67 6c 6f 62  |clones.__do_glob|
# 00003350  61 6c 5f 64 74 6f 72 73  5f 61 75 78 00 63 6f 6d  |al_dtors_aux.com|
# 00003360  70 6c 65 74 65 64 2e 30  00 5f 5f 64 6f 5f 67 6c  |pleted.0.__do_gl|
# 00003370  6f 62 61 6c 5f 64 74 6f  72 73 5f 61 75 78 5f 66  |obal_dtors_aux_f|
# 00003380  69 6e 69 5f 61 72 72 61  79 5f 65 6e 74 72 79 00  |ini_array_entry.|
# 00003390  66 72 61 6d 65 5f 64 75  6d 6d 79 00 5f 5f 66 72  |frame_dummy.__fr|
# 000033a0  61 6d 65 5f 64 75 6d 6d  79 5f 69 6e 69 74 5f 61  |ame_dummy_init_a|
# 000033b0  72 72 61 79 5f 65 6e 74  72 79 00 68 65 6c 6c 6f  |rray_entry.hello|
# 000033c0  2e 63 70 70 00 5f 5a 4e  53 74 38 5f 5f 64 65 74  |.cpp._ZNSt8__det|
# 000033d0  61 69 6c 33 30 5f 5f 69  6e 74 65 67 65 72 5f 74  |ail30__integer_t|
# 000033e0  6f 5f 63 68 61 72 73 5f  69 73 5f 75 6e 73 69 67  |o_chars_is_unsig|
# 000033f0  6e 65 64 49 6a 45 45 00  5f 5a 4e 53 74 38 5f 5f  |nedIjEE._ZNSt8__|
# 00003400  64 65 74 61 69 6c 33 30  5f 5f 69 6e 74 65 67 65  |detail30__intege|
# 00003410  72 5f 74 6f 5f 63 68 61  72 73 5f 69 73 5f 75 6e  |r_to_chars_is_un|
# 00003420  73 69 67 6e 65 64 49 6d  45 45 00 5f 5a 4e 53 74  |signedImEE._ZNSt|
# 00003430  38 5f 5f 64 65 74 61 69  6c 33 30 5f 5f 69 6e 74  |8__detail30__int|
# 00003440  65 67 65 72 5f 74 6f 5f  63 68 61 72 73 5f 69 73  |eger_to_chars_is|
# 00003450  5f 75 6e 73 69 67 6e 65  64 49 79 45 45 00 5f 5f  |_unsignedIyEE.__|
# 00003460  46 52 41 4d 45 5f 45 4e  44 5f 5f 00 5f 5f 47 4e  |FRAME_END__.__GN|
# 00003470  55 5f 45 48 5f 46 52 41  4d 45 5f 48 44 52 00 5f  |U_EH_FRAME_HDR._|
# 00003480  44 59 4e 41 4d 49 43 00  5f 47 4c 4f 42 41 4c 5f  |DYNAMIC._GLOBAL_|
# 00003490  4f 46 46 53 45 54 5f 54  41 42 4c 45 5f 00 5f 5f  |OFFSET_TABLE_.__|
# 000034a0  63 78 61 5f 66 69 6e 61  6c 69 7a 65 40 47 4c 49  |cxa_finalize@GLI|
# 000034b0  42 43 5f 32 2e 31 2e 33  00 5f 65 64 61 74 61 00  |BC_2.1.3._edata.|
# 000034c0  5f 49 4f 5f 73 74 64 69  6e 5f 75 73 65 64 00 5f  |_IO_stdin_used._|
# 000034d0  66 70 5f 68 77 00 6d 61  69 6e 00 5f 5a 53 74 34  |fp_hw.main._ZSt4|
# 00003690  54 61 62 6c 65 00 00 2e  73 79 6d 74 61 62 00 2e  |Table...symtab..|
# 000036a0  73 74 72 74 61 62 00 2e  73 68 73 74 72 74 61 62  |strtab..shstrtab|
# 000036b0  00 2e 69 6e 74 65 72 70  00 2e 6e 6f 74 65 2e 67  |..interp..note.g|
# 000036c0  6e 75 2e 62 75 69 6c 64  2d 69 64 00 2e 6e 6f 74  |nu.build-id..not|
# 000036d0  65 2e 41 42 49 2d 74 61  67 00 2e 67 6e 75 2e 68  |e.ABI-tag..gnu.h|
# 000036e0  61 73 68 00 2e 64 79 6e  73 79 6d 00 2e 64 79 6e  |ash..dynsym..dyn|
# 000036f0  73 74 72 00 2e 67 6e 75  2e 76 65 72 73 69 6f 6e  |str..gnu.version|
# 00003700  00 2e 67 6e 75 2e 76 65  72 73 69 6f 6e 5f 72 00  |..gnu.version_r.|
# 00003710  2e 72 65 6c 2e 64 79 6e  00 2e 72 65 6c 2e 70 6c  |.rel.dyn..rel.pl|
# 00003720  74 00 2e 69 6e 69 74 00  2e 70 6c 74 2e 67 6f 74  |t..init..plt.got|
# 00003730  00 2e 74 65 78 74 00 2e  66 69 6e 69 00 2e 72 6f  |..text..fini..ro|
# 00003740  64 61 74 61 00 2e 65 68  5f 66 72 61 6d 65 5f 68  |data..eh_frame_h|
# 00003750  64 72 00 2e 65 68 5f 66  72 61 6d 65 00 2e 69 6e  |dr..eh_frame..in|
# 00003760  69 74 5f 61 72 72 61 79  00 2e 66 69 6e 69 5f 61  |it_array..fini_a|
# 00003770  72 72 61 79 00 2e 64 79  6e 61 6d 69 63 00 2e 67  |rray..dynamic..g|
# 00003780  6f 74 2e 70 6c 74 00 2e  64 61 74 61 00 2e 62 73  |ot.plt..data..bs|
# 00003790  73 00 2e 63 6f 6d 6d 65  6e 74 00 00 00 00 00 00  |s..comment......|
# 000037a0  00 00 00 00 00 00 00 00  00 00 00 00 00 00 00 00  |................|
# *
# 000037c0  00 00 00 00 1b 00 00 00  01 00 00 00 02 00 00 00  |................|
# 000037d0  94 01 00 00 94 01 00 00  13 00 00 00 00 00 00 00  |................|
# 000037e0  00 00 00 00 01 00 00 00  00 00 00 00 23 00 00 00  |............#...|
# 000037f0  07 00 00 00 02 00 00 00  a8 01 00 00 a8 01 00 00  |................|
# 00003800  24 00 00 00 00 00 00 00  00 00 00 00 04 00 00 00  |$...............|
# 00003810  00 00 00 00 36 00 00 00  07 00 00 00 02 00 00 00  |....6...........|
# 00003820  cc 01 00 00 cc 01 00 00  20 00 00 00 00 00 00 00  |........ .......|
# 00003830  00 00 00 00 04 00 00 00  00 00 00 00 44 00 00 00  |............D...|
# 00003840  f6 ff ff 6f 02 00 00 00  ec 01 00 00 ec 01 00 00  |...o............|
# 00003850  20 00 00 00 05 00 00 00  00 00 00 00 04 00 00 00  | ...............|
# 00003860  04 00 00 00 4e 00 00 00  0b 00 00 00 02 00 00 00  |....N...........|
# 00003870  0c 02 00 00 0c 02 00 00  c0 00 00 00 06 00 00 00  |................|
# 00003880  01 00 00 00 04 00 00 00  10 00 00 00 56 00 00 00  |............V...|
# 00003890  03 00 00 00 02 00 00 00  cc 02 00 00 cc 02 00 00  |................|
# 000038a0  6c 01 00 00 00 00 00 00  00 00 00 00 01 00 00 00  
# 00003270  e0 01 00 00 c9 11 00 00  00 00 00 00 12 02 0e 00  |................|
# 00003280  f6 01 00 00 10 40 00 00  00 00 00 00 11 02 18 00  |.....@..........|
# 00003290  02 02 00 00 00 00 00 00  00 00 00 00 20 00 00 00  |............ ...|
# 000032a0  1c 02 00 00 00 10 00 00  00 00 00 00 12 02 0b 00  |................|
# 000032b0  00 53 63 72 74 31 2e 6f  00 5f 5f 61 62 69 5f 74  |.Scrt1.o.__abi_t|
# 000032c0  61 67 00 63 72 74 73 74  75 66 66 2e 63 00 64 65  |ag.crtstuff.c.de|
# 000032d0  72 65 67 69 73 74 65 72  5f 74 6d 5f 63 6c 6f 6e  |register_tm_clon|
# 000032e0  65 73 00 5f 5f 64 6f 5f  67 6c 6f 62 61 6c 5f 64  |es.__do_global_d|
# 000032f0  74 6f 72 73 5f 61 75 78  00 63 6f 6d 70 6c 65 74  |tors_aux.complet|
# 00003300  65 64 2e 30 00 5f 5f 64  6f 5f 67 6c 6f 62 61 6c  |ed.0.__do_global|
# 00003310  5f 64 74 6f 72 73 5f 61  75 78 5f 66 69 6e 69 5f  |_dtors_aux_fini_|
# 00003320  61 72 72 61 79 5f 65 6e  74 72 79 00 66 72 61 6d  |array_entry.fram|
# 00003330  65 5f 64 75 6d 6d 79 00  5f 5f 66 72 61 6d 65 5f  |e_dummy.__frame_|
# 00003340  64 75 6d 6d 79 5f 69 6e  69 74 5f 61 72 72 61 79  |dummy_init_array|
# 00003350  5f 65 6e 74 72 79 00 68  65 6c 6c 6f 2e 63 00 5f  |_entry.hello.c._|
# 00003360  5f 46 52 41 4d 45 5f 45  4e 44 5f 5f 00 5f 44 59  |_FRAME_END__._DY|
# 00003370  4e 41 4d 49 43 00 5f 5f  47 4e 55 5f 45 48 5f 46  |NAMIC.__GNU_EH_F|
# 00003380  52 41 4d 45 5f 48 44 52  00 5f 47 4c 4f 42 41 4c  |RAME_HDR._GLOBAL|
# 00003390  5f 4f 46 46 53 45 54 5f  54 41 42 4c 45 5f 00 5f  |_OFFSET_TABLE_._|
# 000033a0  5f 6c 69 62 63 5f 73 74  61 72 74 5f 6d 61 69 6e  |_libc_start_main|
# 000033b0  40 47 4c 49 42 43 5f 32  2e 33 34 00 5f 49 54 4d  |@GLIBC_2.34._ITM|
# 000033c0  5f 64 65 72 65 67 69 73  74 65 72 54 4d 43 6c 6f  |_deregisterTMClo|
# 000033d0  6e 65 54 61 62 6c 65 00  5f 5f 78 38 36 2e 67 65  |neTable.__x86.ge|
# 000033e0  74 5f 70 63 5f 74 68 75  6e 6b 2e 62 78 00 5f 65  |t_pc_thunk.bx._e|
# 000033f0  64 61 74 61 00 5f 66 69  6e 69 00 5f 5f 78 38 36  |data._fini.__x86|
# 00003400  2e 67 65 74 5f 70 63 5f  74 68 75 6e 6b 2e 64 78  |.get_pc_thunk.dx|
# 00003410  00 5f 5f 63 78 61 5f 66  69 6e 61 6c 69 7a 65 40  |.__cxa_finalize@|
# 00003420  47 4c 49 42 43 5f 32 2e  31 2e 33 00 5f 5f 64 61  |GLIBC_2.1.3.__da|
# 00003430  74 61 5f 73 74 61 72 74  00 70 75 74 73 40 47 4c  |ta_start.puts@GL|
# 00003440  49 42 43 5f 32 2e 30 00  5f 5f 67 6d 6f 6e 5f 73  |IBC_2.0.__gmon_s|
# 00003450  74 61 72 74 5f 5f 00 5f  5f 64 73 6f 5f 68 61 6e  |tart__.__dso_han|
# 00003460  64 6c 65 00 5f 49 4f 5f  73 74 64 69 6e 5f 75 73  |dle._IO_stdin_us|
# 00003470  65 64 00 5f 65 6e 64 00  5f 66 70 5f 68 77 00 5f  |ed._end._fp_hw._|
# 00003480  5f 62 73 73 5f 73 74 61  72 74 00 6d 61 69 6e 00  |_bss_start.main.|
# 00003490  5f 5f 78 38 36 2e 67 65  74 5f 70 63 5f 74 68 75  |__x86.get_pc_thu|
# 000034a0  6e 6b 2e 61 78 00 5f 5f  54 4d 43 5f 45 4e 44 5f  |nk.ax.__TMC_END_|
# 000034b0  5f 00 5f 49 54 4d 5f 72  65 67 69 73 74 65 72 54  |_._ITM_registerT|
# 000034c0  4d 43 6c 6f 6e 65 54 61  62 6c 65 00 5f 69 6e 69  |MCloneTable._ini|
# 000034d0  74 00 00 2e 73 79 6d 74  61 62 00 2e 73 74 72 74  |t...symtab..strt|
# 000034e0  61 62 00 2e 73 68 73 74  72 74 61 62 00 2e 69 6e  |ab..shstrtab..in|
# 000034f0  74 65 72 70 00 2e 6e 6f  74 65 2e 67 6e 75 2e 62  |terp..note.gnu.b|
# 00003500  75 69 6c 64 2d 69 64 00  2e 6e 6f 74 65 2e 41 42  |uild-id..note.AB|
# 00003510  49 2d 74 61 67 00 2e 67  6e 75 2e 68 61 73 68 00  |I-tag..gnu.hash.|
# 00003520  2e 64 79 6e 73 79 6d 00  2e 64 79 6e 73 74 72 00  |.dynsym..dynstr.|
# 00003530  2e 67 6e 75 2e 76 65 72  73 69 6f 6e 00 2e 67 6e  |.gnu.version..gn|
# 00003540  75 2e 76 65 72 73 69 6f  6e 5f 72 00 2e 72 65 6c  |u.version_r..rel|
# 00003550  2e 64 79 6e 00 2e 72 65  6c 2e 70 6c 74 00 2e 69  |.dyn..rel.plt..i|
# 00003560  6e 69 74 00 2e 70 6c 74  2e 67 6f 74 00 2e 74 65  |nit..plt.got..te|
# 00003570  78 74 00 2e 66 69 6e 69  00 2e 72 6f 64 61 74 61  |xt..fini..rodata|
# 00003580  00 2e 65 68 5f 66 72 61  6d 65 5f 68 64 72 00 2e  |..eh_frame_hdr..|
# 00003590  65 68 5f 66 72 61 6d 65  00 2e 69 6e 69 74 5f 61  |eh_frame..init_a|
# 000035a0  72 72 61 79 00 2e 66 69  6e 69 5f 61 72 72 61 79  |rray..fini_array|
# 000035b0  00 2e 64 79 6e 61 6d 69  63 00 2e 67 6f 74 2e 70  |..dynamic..got.p|
# 000035c0  6c 74 00 2e 64 61 74 61  00 2e 62 73 73 00 2e 63  |lt..data..bss..c|
# 000035d0  6f 6d 6d 65 6e 74 00 00  00 00 00 00 00 00 00 00  |omment..........|
# 000035e0  00 00 00 00 00 00 00 00  00 00 00 00 00 00 00 00  |................|
# *
# 
00 00 00  00 00 00 00 00 00 00 00  |................|
# 00003a70  d2 34 00 00 05 01 00 00  00 00 00 00 00 00 00 00  |.4..............|
# 00003a80  01 00 00 00 00 00 00 00                           |........|
# 00003a88

# %% [markdown]
# ## ELF file parts
#
# ## Symbols
# - function names, e.g., if printf built-in function is used, how does the program find it?
#
# ## Sections
# - symbols are organized into **sections** - code lives in one section (.text) and data lives in another (.data, .rodata)
#
# ## Segments
# - sections are organized into **segments**

# %% [markdown]
# ### Examine various sections of ELF
# - let's compile demos/hello.cpp file
# - use the compiled ELF file to examine various sections
#
# ### readelf and objdump
# - these utilities can help us look at various parts
#
# ### look at all the symbols of a binary
# - important symbols to note: main, _start, puts

# %%
! readelf --symbols hello.exe

# %%
! readelf --symbols hello_c.exe

# %% [markdown]
# ### display all the sections
# - some important sections are: .text, .rodata, .data, .bss

# %%
! readelf --sections hello.exe

# %% [markdown]
# ## look at just one section, e.g., .rodata
# - read-only data is stored in .rodata, e.g. literal values (Hello World!)

# %%
! readelf --sections hello_c.exe

# %%
# let's look at just the .rodata section of hello program
! readelf -x .rodata hello.exe

# %%
# let's look at the .rodata section of memory_segment.exe program
! readelf -x .rodata memory_segments.exe

# %%
! readelf --sections hello_c.exe

# %% [markdown]
# ### objdump program
# - objdump can also be used to examine each program sections

# %%
! objdump -s -j .rodata hello.exe

# %%
! readelf -x .data memory_segments.exe
# Note: even though global_initialized_var = 5; we see in hex but not ascii

# %%
! readelf -x .bss memory_segments.exe

# %% [markdown]
# ### look at the segments
# - GNU_STACK is important to note
#     - RW - Read and Write; NO Execute
#     - data in stack will be treated as literal values or just data but not code!

# %%
! readelf --segments hello_c.exe

# %% [markdown]
# ## Disassemble using objdump
# - look at the assembly code of the whole binary
# - by default, objdump shows AT&T assembly syntax with %, \$
#     - source before the destination
#     - e.g., `mov $5, %eax`
# - https://en.wikipedia.org/wiki/X86_assembly_language

# %%
! objdump -d hello.exe
# Out:
# hello.exe:     file format elf32-i386
#
#
# Disassembly of section .init:
#
# 00001000 <_init>:
#     1000:	53                   	push   %ebx
#     1001:	83 ec 08             	sub    $0x8,%esp
#     1004:	e8 97 00 00 00       	call   10a0 <__x86.get_pc_thunk.bx>
#     1009:	81 c3 eb 2f 00 00    	add    $0x2feb,%ebx
#     100f:	8b 83 f8 ff ff ff    	mov    -0x8(%ebx),%eax
#     1015:	85 c0                	test   %eax,%eax
#     1017:	74 02                	je     101b <_init+0x1b>
#     1019:	ff d0                	call   *%eax
#     101b:	83 c4 08             	add    $0x8,%esp
#     101e:	5b                   	pop    %ebx
#     101f:	c3                   	ret
#
# Disassembly of section .plt:
#
# 00001020 <__libc_start_main@plt-0x10>:
#     1020:	ff b3 04 00 00 00    	push   0x4(%ebx)
#     1026:	ff a3 08 00 00 00    	jmp    *0x8(%ebx)
#     102c:	00 00                	add    %al,(%eax)
# 	...
#
# 00001030 <__libc_start_main@plt>:
#     1030:	ff a3 0c 00 00 00    	jmp    *0xc(%ebx)
#     1036:	68 00 00 00 00       	push   $0x0
#     103b:	e9 e0 ff ff ff       	jmp    1020 <_init+0x20>
#
# 00001040 <_ZStlsISt11char_traitsIcEERSt13basic_ostreamIcT_ES5_PKc@plt>:
#     1040:	ff a3 10 00 00 00    	jmp    *0x10(%ebx)
#     1046:	68 08 00 00 00       	push   $0x8
#     104b:	e9 d0 ff ff ff       	jmp    1020 <_init+0x20>
#
# 00001050 <_ZNSolsEPFRSoS_E@plt>:
#     1050:	ff a3 14 00 00 00    	jmp    *0x14(%ebx)
#     1056:	68 10 00 00 00       	push   $0x10
#     105b:	e9 c0 ff ff ff       	jmp    1020 <_init+0x20>
#
# Disassembly of section .plt.got:
#
# 00001060 <__cxa_finalize@plt>:
#     1060:	ff a3 e4 ff ff ff    	jmp    *-0x1c(%ebx)
#     1066:	66 90                	xchg   %ax,%ax
#
# Disassembly of section .text:
#
# 00001070 <_start>:
#     1070:	31 ed                	xor    %ebp,%ebp
#     1072:	5e                   	pop    %esi
#     1073:	89 e1                	mov    %esp,%ecx
#     1075:	83 e4 f0             	and    $0xfffffff0,%esp
#     1078:	50                   	push   %eax
#     1079:	54                   	push   %esp
#     107a:	52                   	push   %edx
#     107b:	e8 18 00 00 00       	call   1098 <_start+0x28>
#     1080:	81 c3 74 2f 00 00    	add    $0x2f74,%ebx
#     1086:	6a 00                	push   $0x0
#     1088:	6a 00                	push   $0x0
#     108a:	51                   	push   %ecx
#     108b:	56                   	push   %esi
#     108c:	ff b3 e8 ff ff ff    	push   -0x18(%ebx)
#     1092:	e8 99 ff ff ff       	call   1030 <__libc_start_main@plt>
#     1097:	f4                   	hlt
#     1098:	8b 1c 24             	mov    (%esp),%ebx
#     109b:	c3                   	ret
#     109c:	66 90                	xchg   %ax,%ax
#     109e:	66 90                	xchg   %ax,%ax
#
# 000010a0 <__x86.get_pc_thunk.bx>:
#     10a0:	8b 1c 24             	mov    (%esp),%ebx
#     10a3:	c3                   	ret
#     10a4:	66 90                	xchg   %ax,%ax
#     10a6:	66 90                	xchg   %ax,%ax
#     10a8:	66 90                	xchg   %ax,%ax
#     10aa:	66 90                	xchg   %ax,%ax
#     10ac:	66 90                	xchg   %ax,%ax
#     10ae:	66 90                	xchg   %ax,%ax
#
# 000010b0 <deregister_tm_clones>:
#     10b0:	e8 e4 00 00 00       	call   1199 <__x86.get_pc_thunk.dx>
#     10b5:	81 c2 3f 2f 00 00    	add    $0x2f3f,%edx
#     10bb:	8d 8a 20 00 00 00    	lea    0x20(%edx),%ecx
#     10c1:	8d 82 20 00 00 00    	lea    0x20(%edx),%eax
#     10c7:	39 c8                	cmp    %ecx,%eax
#     10c9:	74 1d                	je     10e8 <deregister_tm_clones+0x38>
#     10cb:	8b 82 f4 ff ff ff    	mov    -0xc(%edx),%eax
#     10d1:	85 c0                	test   %eax,%eax
#     10d3:	74 13                	je     10e8 <deregister_tm_clones+0x38>
#     10d5:	55                   	push   %ebp
#     10d6:	89 e5                	mov    %esp,%ebp
#     10d8:	83 ec 14             	sub    $0x14,%esp
#     10db:	51                   	push   %ecx
#     10dc:	ff d0                	call   *%eax
#     10de:	83 c4 10             	add    $0x10,%esp
#     10e1:	c9                   	leave
#     10e2:	c3                   	ret
#     10e3:	2e 8d 74 26 00       	lea    %cs:0x0(%esi,%eiz,1),%esi
#     10e8:	c3                   	ret
#     10e9:	8d b4 26 00 00 00 00 	lea    0x0(%esi,%eiz,1),%esi
#
# 000010f0 <register_tm_clones>:
#     10f0:	e8 a4 00 00 00       	call   1199 <__x86.get_pc_thunk.dx>
#     10f5:	81 c2 ff 2e 00 00    	add    $0x2eff,%edx
#     10fb:	55                   	push   %ebp
#     10fc:	89 e5                	mov    %esp,%ebp
#     10fe:	53                   	push   %ebx
#     10ff:	8d 8a 20 00 00 00    	lea    0x20(%edx),%ecx
#     1105:	8d 82 20 00 00 00    	lea    0x20(%edx),%eax
#     110b:	83 ec 04             	sub    $0x4,%esp
#     110e:	29 c8                	sub    %ecx,%eax
#     1110:	89 c3                	mov    %eax,%ebx
#     1112:	c1 e8 1f             	shr    $0x1f,%eax
#     1115:	c1 fb 02             	sar    $0x2,%ebx
#     1118:	01 d8                	add    %ebx,%eax
#     111a:	d1 f8                	sar    $1,%eax
#     111c:	74 14                	je     1132 <register_tm_clones+0x42>
#     111e:	8b 92 fc ff ff ff    	mov    -0x4(%edx),%edx
#     1124:	85 d2                	test   %edx,%edx
#     1126:	74 0a                	je     1132 <register_tm_clones+0x42>
#     1128:	83 ec 08             	sub    $0x8,%esp
#     112b:	50                   	push   %eax
#     112c:	51                   	push   %ecx
#     112d:	ff d2                	call   *%edx
#     112f:	83 c4 10             	add    $0x10,%esp
#     1132:	8b 5d fc             	mov    -0x4(%ebp),%ebx
#     1135:	c9                   	leave
#     1136:	c3                   	ret
#     1137:	2e 8d b4 26 00 00 00 	lea    %cs:0x0(%esi,%eiz,1),%esi
#     113e:	00
#     113f:	90                   	nop
#
# 00001140 <__do_global_dtors_aux>:
#     1140:	f3 0f 1e fb          	endbr32
#     1144:	55                   	push   %ebp
#     1145:	89 e5                	mov    %esp,%ebp
#     1147:	53                   	push   %ebx
#     1148:	e8 53 ff ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     114d:	81 c3 a7 2e 00 00    	add    $0x2ea7,%ebx
#     1153:	83 ec 04             	sub    $0x4,%esp
#     1156:	80 bb 20 00 00 00 00 	cmpb   $0x0,0x20(%ebx)
#     115d:	75 27                	jne    1186 <__do_global_dtors_aux+0x46>
#     115f:	8b 83 e4 ff ff ff    	mov    -0x1c(%ebx),%eax
#     1165:	85 c0                	test   %eax,%eax
#     1167:	74 11                	je     117a <__do_global_dtors_aux+0x3a>
#     1169:	83 ec 0c             	sub    $0xc,%esp
#     116c:	ff b3 1c 00 00 00    	push   0x1c(%ebx)
#     1172:	e8 e9 fe ff ff       	call   1060 <__cxa_finalize@plt>
#     1177:	83 c4 10             	add    $0x10,%esp
#     117a:	e8 31 ff ff ff       	call   10b0 <deregister_tm_clones>
#     117f:	c6 83 20 00 00 00 01 	movb   $0x1,0x20(%ebx)
#     1186:	8b 5d fc             	mov    -0x4(%ebp),%ebx
#     1189:	c9                   	leave
#     118a:	c3                   	ret
#     118b:	2e 8d 74 26 00       	lea    %cs:0x0(%esi,%eiz,1),%esi
#
# 00001190 <frame_dummy>:
#     1190:	f3 0f 1e fb          	endbr32
#     1194:	e9 57 ff ff ff       	jmp    10f0 <register_tm_clones>
#
# 00001199 <__x86.get_pc_thunk.dx>:
#     1199:	8b 14 24             	mov    (%esp),%edx
#     119c:	c3                   	ret
#
# 0000119d <main>:
#     119d:	8d 4c 24 04          	lea    0x4(%esp),%ecx
#     11a1:	83 e4 f0             	and    $0xfffffff0,%esp
#     11a4:	ff 71 fc             	push   -0x4(%ecx)
#     11a7:	55                   	push   %ebp
#     11a8:	89 e5                	mov    %esp,%ebp
#     11aa:	53                   	push   %ebx
#     11ab:	51                   	push   %ecx
#     11ac:	e8 ef fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     11b1:	81 c3 43 2e 00 00    	add    $0x2e43,%ebx
#     11b7:	83 ec 08             	sub    $0x8,%esp
#     11ba:	8d 83 14 e0 ff ff    	lea    -0x1fec(%ebx),%eax
#     11c0:	50                   	push   %eax
#     11c1:	8b 83 f0 ff ff ff    	mov    -0x10(%ebx),%eax
#     11c7:	50                   	push   %eax
#     11c8:	e8 73 fe ff ff       	call   1040 <_ZStlsISt11char_traitsIcEERSt13basic_ostreamIcT_ES5_PKc@plt>
#     11cd:	83 c4 10             	add    $0x10,%esp
#     11d0:	83 ec 08             	sub    $0x8,%esp
#     11d3:	8b 93 ec ff ff ff    	mov    -0x14(%ebx),%edx
#     11d9:	52                   	push   %edx
#     11da:	50                   	push   %eax
#     11db:	e8 70 fe ff ff       	call   1050 <_ZNSolsEPFRSoS_E@plt>
#     11e0:	83 c4 10             	add    $0x10,%esp
#     11e3:	b8 00 00 00 00       	mov    $0x0,%eax
#     11e8:	8d 65 f8             	lea    -0x8(%ebp),%esp
#     11eb:	59                   	pop    %ecx
#     11ec:	5b                   	pop    %ebx
#     11ed:	5d                   	pop    %ebp
#     11ee:	8d 61 fc             	lea    -0x4(%ecx),%esp
#     11f1:	c3                   	ret
#
# Disassembly of section .fini:
#
# 000011f4 <_fini>:
#     11f4:	53                   	push   %ebx
#     11f5:	83 ec 08             	sub    $0x8,%esp
#     11f8:	e8 a3 fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     11fd:	81 c3 f7 2d 00 00    	add    $0x2df7,%ebx
#     1203:	83 c4 08             	add    $0x8,%esp
#     1206:	5b                   	pop    %ebx
#     1207:	c3                   	ret

# %%
# display 20 lines after each matching line main. of hello program
! objdump -D hello.exe | grep -A20 main.:
# Out:
# 0000119d <main>:
#     119d:	8d 4c 24 04          	lea    0x4(%esp),%ecx
#     11a1:	83 e4 f0             	and    $0xfffffff0,%esp
#     11a4:	ff 71 fc             	push   -0x4(%ecx)
#     11a7:	55                   	push   %ebp
#     11a8:	89 e5                	mov    %esp,%ebp
#     11aa:	53                   	push   %ebx
#     11ab:	51                   	push   %ecx
#     11ac:	e8 ef fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     11b1:	81 c3 43 2e 00 00    	add    $0x2e43,%ebx
#     11b7:	83 ec 08             	sub    $0x8,%esp
#     11ba:	8d 83 14 e0 ff ff    	lea    -0x1fec(%ebx),%eax
#     11c0:	50                   	push   %eax
#     11c1:	8b 83 f0 ff ff ff    	mov    -0x10(%ebx),%eax
#     11c7:	50                   	push   %eax
#     11c8:	e8 73 fe ff ff       	call   1040 <_ZStlsISt11char_traitsIcEERSt13basic_ostreamIcT_ES5_PKc@plt>
#     11cd:	83 c4 10             	add    $0x10,%esp
#     11d0:	83 ec 08             	sub    $0x8,%esp
#     11d3:	8b 93 ec ff ff ff    	mov    -0x14(%ebx),%edx
#     11d9:	52                   	push   %edx
#     11da:	50                   	push   %eax

# %% [markdown]
# ### disassemble in Intel syntax
# - much cleaner
# - destination before source
#     - e.g., `mov eax, 5`

# %%
! objdump -M intel -D hello.exe
# Out:
# hello.exe:     file format elf32-i386
#
#
# Disassembly of section .interp:
#
# 00000194 <.interp>:
#  194:	2f                   	das
#  195:	6c                   	ins    BYTE PTR es:[edi],dx
#  196:	69 62 2f 6c 64 2d 6c 	imul   esp,DWORD PTR [edx+0x2f],0x6c2d646c
#  19d:	69 6e 75 78 2e 73 6f 	imul   ebp,DWORD PTR [esi+0x75],0x6f732e78
#  1a4:	2e 32 00             	xor    al,BYTE PTR cs:[eax]
#
# Disassembly of section .note.gnu.build-id:
#
# 000001a8 <.note.gnu.build-id>:
#  1a8:	04 00                	add    al,0x0
#  1aa:	00 00                	add    BYTE PTR [eax],al
#  1ac:	14 00                	adc    al,0x0
#  1ae:	00 00                	add    BYTE PTR [eax],al
#  1b0:	03 00                	add    eax,DWORD PTR [eax]
#  1b2:	00 00                	add    BYTE PTR [eax],al
#  1b4:	47                   	inc    edi
#  1b5:	4e                   	dec    esi
#  1b6:	55                   	push   ebp
#  1b7:	00 8b 33 47 28 63    	add    BYTE PTR [ebx+0x63284733],cl
#  1bd:	ba ba 15 ab a3       	mov    edx,0xa3ab15ba
#  1c2:	27                   	daa
#  1c3:	71 6e                	jno    233 <__abi_tag+0x67>
#  1c5:	a0 02 fc db 58       	mov    al,ds:0x58dbfc02
#  1ca:	fb                   	sti
#  1cb:	39                   	.byte 0x39
#
# Disassembly of section .note.ABI-tag:
#
# 000001cc <__abi_tag>:
#  1cc:	04 00                	add    al,0x0
#  1ce:	00 00                	add    BYTE PTR [eax],al
#  1d0:	10 00                	adc    BYTE PTR [eax],al
#  1d2:	00 00                	add    BYTE PTR [eax],al
#  1d4:	01 00                	add    DWORD PTR [eax],eax
#  1d6:	00 00                	add    BYTE PTR [eax],al
#  1d8:	47                   	inc    edi
#  1d9:	4e                   	dec    esi
#  1da:	55                   	push   ebp
#  1db:	00 00                	add    BYTE PTR [eax],al
#  1dd:	00 00                	add    BYTE PTR [eax],al
#  1df:	00 03                	add    BYTE PTR [ebx],al
#  1e1:	00 00                	add    BYTE PTR [eax],al
#  1e3:	00 02                	add    BYTE PTR [edx],al
#  1e5:	00 00                	add    BYTE PTR [eax],al
#  1e7:	00 00                	add    BYTE PTR [eax],al
#  1e9:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .gnu.hash:
#
# 000001ec <.gnu.hash>:
#  1ec:	02 00                	add    al,BYTE PTR [eax]
#  1ee:	00 00                	add    BYTE PTR [eax],al
#  1f0:	0b 00                	or     eax,DWORD PTR [eax]
#  1f2:	00 00                	add    BYTE PTR [eax],al
#  1f4:	01 00                	add    DWORD PTR [eax],eax
#  1f6:	00 00                	add    BYTE PTR [eax],al
#  1f8:	05 00 00 00 00       	add    eax,0x0
#  1fd:	20 00                	and    BYTE PTR [eax],al
#  1ff:	20 00                	and    BYTE PTR [eax],al
#  201:	00 00                	add    BYTE PTR [eax],al
#  203:	00 0b                	add    BYTE PTR [ebx],cl
#  205:	00 00                	add    BYTE PTR [eax],al
#  207:	00                   	.byte 0
#  208:	ad                   	lods   eax,DWORD PTR ds:[esi]
#  209:	4b                   	dec    ebx
#  20a:	e3 c0                	jecxz  1cc <__abi_tag>
#
# Disassembly of section .dynsym:
#
# 0000020c <.dynsym>:
# 	...
#  21c:	12 01                	adc    al,BYTE PTR [ecx]
# 	...
#  226:	00 00                	add    BYTE PTR [eax],al
#  228:	22 00                	and    al,BYTE PTR [eax]
#  22a:	00 00                	add    BYTE PTR [eax],al
#  22c:	46                   	inc    esi
# 	...
#  235:	00 00                	add    BYTE PTR [eax],al
#  237:	00 12                	add    BYTE PTR [edx],dl
#  239:	00 00                	add    BYTE PTR [eax],al
#  23b:	00 00                	add    BYTE PTR [eax],al
#  23d:	01 00                	add    DWORD PTR [eax],eax
# 	...
#  247:	00 12                	add    BYTE PTR [edx],dl
#  249:	00 00                	add    BYTE PTR [eax],al
#  24b:	00 af 00 00 00 00    	add    BYTE PTR [edi+0x0],ch
#  251:	00 00                	add    BYTE PTR [eax],al
#  253:	00 00                	add    BYTE PTR [eax],al
#  255:	00 00                	add    BYTE PTR [eax],al
#  257:	00 12                	add    BYTE PTR [edx],dl
#  259:	00 00                	add    BYTE PTR [eax],al
#  25b:	00 81 00 00 00 00    	add    BYTE PTR [ecx+0x0],al
#  261:	00 00                	add    BYTE PTR [eax],al
#  263:	00 00                	add    BYTE PTR [eax],al
#  265:	00 00                	add    BYTE PTR [eax],al
#  267:	00 12                	add    BYTE PTR [edx],dl
#  269:	00 00                	add    BYTE PTR [eax],al
#  26b:	00 e7                	add    bh,ah
# 	...
#  275:	00 00                	add    BYTE PTR [eax],al
#  277:	00 11                	add    BYTE PTR [ecx],dl
#  279:	00 00                	add    BYTE PTR [eax],al
#  27b:	00 92 00 00 00 00    	add    BYTE PTR [edx+0x0],dl
#  281:	00 00                	add    BYTE PTR [eax],al
#  283:	00 00                	add    BYTE PTR [eax],al
#  285:	00 00                	add    BYTE PTR [eax],al
#  287:	00 12                	add    BYTE PTR [edx],dl
#  289:	00 00                	add    BYTE PTR [eax],al
#  28b:	00 10                	add    BYTE PTR [eax],dl
# 	...
#  295:	00 00                	add    BYTE PTR [eax],al
#  297:	00 20                	add    BYTE PTR [eax],ah
#  299:	00 00                	add    BYTE PTR [eax],al
#  29b:	00 01                	add    BYTE PTR [ecx],al
# 	...
#  2a5:	00 00                	add    BYTE PTR [eax],al
#  2a7:	00 20                	add    BYTE PTR [eax],ah
#  2a9:	00 00                	add    BYTE PTR [eax],al
#  2ab:	00 2c 00             	add    BYTE PTR [eax+eax*1],ch
# 	...
#  2b6:	00 00                	add    BYTE PTR [eax],al
#  2b8:	20 00                	and    BYTE PTR [eax],al
#  2ba:	00 00                	add    BYTE PTR [eax],al
#  2bc:	f1                   	int1
#  2bd:	00 00                	add    BYTE PTR [eax],al
#  2bf:	00 04 20             	add    BYTE PTR [eax+eiz*1],al
#  2c2:	00 00                	add    BYTE PTR [eax],al
#  2c4:	04 00                	add    al,0x0
#  2c6:	00 00                	add    BYTE PTR [eax],al
#  2c8:	11 00                	adc    DWORD PTR [eax],eax
#  2ca:	10 00                	adc    BYTE PTR [eax],al
#
# Disassembly of section .dynstr:
#
# 000002cc <.dynstr>:
#  2cc:	00 5f 5f             	add    BYTE PTR [edi+0x5f],bl
#  2cf:	67 6d                	ins    DWORD PTR es:[di],dx
#  2d1:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  2d2:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  2d3:	5f                   	pop    edi
#  2d4:	73 74                	jae    34a <__abi_tag+0x17e>
#  2d6:	61                   	popa
#  2d7:	72 74                	jb     34d <__abi_tag+0x181>
#  2d9:	5f                   	pop    edi
#  2da:	5f                   	pop    edi
#  2db:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#  2de:	54                   	push   esp
#  2df:	4d                   	dec    ebp
#  2e0:	5f                   	pop    edi
#  2e1:	64 65 72 65          	fs gs jb 34a <__abi_tag+0x17e>
#  2e5:	67 69 73 74 65 72 54 	imul   esi,DWORD PTR [bp+di+0x74],0x4d547265
#  2ec:	4d
#  2ed:	43                   	inc    ebx
#  2ee:	6c                   	ins    BYTE PTR es:[edi],dx
#  2ef:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  2f0:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  2f1:	65 54                	gs push esp
#  2f3:	61                   	popa
#  2f4:	62 6c 65 00          	bound  ebp,QWORD PTR [ebp+eiz*2+0x0]
#  2f8:	5f                   	pop    edi
#  2f9:	49                   	dec    ecx
#  2fa:	54                   	push   esp
#  2fb:	4d                   	dec    ebp
#  2fc:	5f                   	pop    edi
#  2fd:	72 65                	jb     364 <__abi_tag+0x198>
#  2ff:	67 69 73 74 65 72 54 	imul   esi,DWORD PTR [bp+di+0x74],0x4d547265
#  306:	4d
#  307:	43                   	inc    ebx
#  308:	6c                   	ins    BYTE PTR es:[edi],dx
#  309:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  30a:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  30b:	65 54                	gs push esp
#  30d:	61                   	popa
#  30e:	62 6c 65 00          	bound  ebp,QWORD PTR [ebp+eiz*2+0x0]
#  312:	5f                   	pop    edi
#  313:	5a                   	pop    edx
#  314:	53                   	push   ebx
#  315:	74 34                	je     34b <__abi_tag+0x17f>
#  317:	65 6e                	outs   dx,BYTE PTR gs:[esi]
#  319:	64 6c                	fs ins BYTE PTR es:[edi],dx
#  31b:	49                   	dec    ecx
#  31c:	63 53 74             	arpl   WORD PTR [ebx+0x74],edx
#  31f:	31 31                	xor    DWORD PTR [ecx],esi
#  321:	63 68 61             	arpl   WORD PTR [eax+0x61],ebp
#  324:	72 5f                	jb     385 <__abi_tag+0x1b9>
#  326:	74 72                	je     39a <__abi_tag+0x1ce>
#  328:	61                   	popa
#  329:	69 74 73 49 63 45 45 	imul   esi,DWORD PTR [ebx+esi*2+0x49],0x52454563
#  330:	52
#  331:	53                   	push   ebx
#  332:	74 31                	je     365 <__abi_tag+0x199>
#  334:	33 62 61             	xor    esp,DWORD PTR [edx+0x61]
#  337:	73 69                	jae    3a2 <__abi_tag+0x1d6>
#  339:	63 5f 6f             	arpl   WORD PTR [edi+0x6f],ebx
#  33c:	73 74                	jae    3b2 <__abi_tag+0x1e6>
#  33e:	72 65                	jb     3a5 <__abi_tag+0x1d9>
#  340:	61                   	popa
#  341:	6d                   	ins    DWORD PTR es:[edi],dx
#  342:	49                   	dec    ecx
#  343:	54                   	push   esp
#  344:	5f                   	pop    edi
#  345:	54                   	push   esp
#  346:	30 5f 45             	xor    BYTE PTR [edi+0x45],bl
#  349:	53                   	push   ebx
#  34a:	36 5f                	ss pop edi
#  34c:	00 5f 5a             	add    BYTE PTR [edi+0x5a],bl
#  34f:	4e                   	dec    esi
#  350:	53                   	push   ebx
#  351:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  352:	6c                   	ins    BYTE PTR es:[edi],dx
#  353:	73 45                	jae    39a <__abi_tag+0x1ce>
#  355:	50                   	push   eax
#  356:	46                   	inc    esi
#  357:	52                   	push   edx
#  358:	53                   	push   ebx
#  359:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  35a:	53                   	push   ebx
#  35b:	5f                   	pop    edi
#  35c:	45                   	inc    ebp
#  35d:	00 5f 5a             	add    BYTE PTR [edi+0x5a],bl
#  360:	53                   	push   ebx
#  361:	74 32                	je     395 <__abi_tag+0x1c9>
#  363:	31 69 6f             	xor    DWORD PTR [ecx+0x6f],ebp
#  366:	73 5f                	jae    3c7 <__abi_tag+0x1fb>
#  368:	62 61 73             	bound  esp,QWORD PTR [ecx+0x73]
#  36b:	65 5f                	gs pop edi
#  36d:	6c                   	ins    BYTE PTR es:[edi],dx
#  36e:	69 62 72 61 72 79 5f 	imul   esp,DWORD PTR [edx+0x72],0x5f797261
#  375:	69 6e 69 74 76 00 5f 	imul   ebp,DWORD PTR [esi+0x69],0x5f007674
#  37c:	5a                   	pop    edx
#  37d:	53                   	push   ebx
#  37e:	74 6c                	je     3ec <__abi_tag+0x220>
#  380:	73 49                	jae    3cb <__abi_tag+0x1ff>
#  382:	53                   	push   ebx
#  383:	74 31                	je     3b6 <__abi_tag+0x1ea>
#  385:	31 63 68             	xor    DWORD PTR [ebx+0x68],esp
#  388:	61                   	popa
#  389:	72 5f                	jb     3ea <__abi_tag+0x21e>
#  38b:	74 72                	je     3ff <__abi_tag+0x233>
#  38d:	61                   	popa
#  38e:	69 74 73 49 63 45 45 	imul   esi,DWORD PTR [ebx+esi*2+0x49],0x52454563
#  395:	52
#  396:	53                   	push   ebx
#  397:	74 31                	je     3ca <__abi_tag+0x1fe>
#  399:	33 62 61             	xor    esp,DWORD PTR [edx+0x61]
#  39c:	73 69                	jae    407 <__abi_tag+0x23b>
#  39e:	63 5f 6f             	arpl   WORD PTR [edi+0x6f],ebx
#  3a1:	73 74                	jae    417 <__abi_tag+0x24b>
#  3a3:	72 65                	jb     40a <__abi_tag+0x23e>
#  3a5:	61                   	popa
#  3a6:	6d                   	ins    DWORD PTR es:[edi],dx
#  3a7:	49                   	dec    ecx
#  3a8:	63 54 5f 45          	arpl   WORD PTR [edi+ebx*2+0x45],edx
#  3ac:	53                   	push   ebx
#  3ad:	35 5f 50 4b 63       	xor    eax,0x634b505f
#  3b2:	00 5f 5a             	add    BYTE PTR [edi+0x5a],bl
#  3b5:	53                   	push   ebx
#  3b6:	74 34                	je     3ec <__abi_tag+0x220>
#  3b8:	63 6f 75             	arpl   WORD PTR [edi+0x75],ebp
#  3bb:	74 00                	je     3bd <__abi_tag+0x1f1>
#  3bd:	5f                   	pop    edi
#  3be:	49                   	dec    ecx
#  3bf:	4f                   	dec    edi
#  3c0:	5f                   	pop    edi
#  3c1:	73 74                	jae    437 <__abi_tag+0x26b>
#  3c3:	64 69 6e 5f 75 73 65 	imul   ebp,DWORD PTR fs:[esi+0x5f],0x64657375
#  3ca:	64
#  3cb:	00 5f 5f             	add    BYTE PTR [edi+0x5f],bl
#  3ce:	6c                   	ins    BYTE PTR es:[edi],dx
#  3cf:	69 62 63 5f 73 74 61 	imul   esp,DWORD PTR [edx+0x63],0x6174735f
#  3d6:	72 74                	jb     44c <__abi_tag+0x280>
#  3d8:	5f                   	pop    edi
#  3d9:	6d                   	ins    DWORD PTR es:[edi],dx
#  3da:	61                   	popa
#  3db:	69 6e 00 5f 5f 63 78 	imul   ebp,DWORD PTR [esi+0x0],0x78635f5f
#  3e2:	61                   	popa
#  3e3:	5f                   	pop    edi
#  3e4:	66 69 6e 61 6c 69    	imul   bp,WORD PTR [esi+0x61],0x696c
#  3ea:	7a 65                	jp     451 <__abi_tag+0x285>
#  3ec:	00 6c 69 62          	add    BYTE PTR [ecx+ebp*2+0x62],ch
#  3f0:	73 74                	jae    466 <__abi_tag+0x29a>
#  3f2:	64 63 2b             	arpl   WORD PTR fs:[ebx],ebp
#  3f5:	2b 2e                	sub    ebp,DWORD PTR [esi]
#  3f7:	73 6f                	jae    468 <__abi_tag+0x29c>
#  3f9:	2e 36 00 6c 69 62    	cs add BYTE PTR ss:[ecx+ebp*2+0x62],ch
#  3ff:	63 2e                	arpl   WORD PTR [esi],ebp
#  401:	73 6f                	jae    472 <__abi_tag+0x2a6>
#  403:	2e 36 00 47 4c       	cs add BYTE PTR ss:[edi+0x4c],al
#  408:	49                   	dec    ecx
#  409:	42                   	inc    edx
#  40a:	43                   	inc    ebx
#  40b:	58                   	pop    eax
#  40c:	58                   	pop    eax
#  40d:	5f                   	pop    edi
#  40e:	33 2e                	xor    ebp,DWORD PTR [esi]
#  410:	34 2e                	xor    al,0x2e
#  412:	33 32                	xor    esi,DWORD PTR [edx]
#  414:	00 47 4c             	add    BYTE PTR [edi+0x4c],al
#  417:	49                   	dec    ecx
#  418:	42                   	inc    edx
#  419:	43                   	inc    ebx
#  41a:	58                   	pop    eax
#  41b:	58                   	pop    eax
#  41c:	5f                   	pop    edi
#  41d:	33 2e                	xor    ebp,DWORD PTR [esi]
#  41f:	34 00                	xor    al,0x0
#  421:	47                   	inc    edi
#  422:	4c                   	dec    esp
#  423:	49                   	dec    ecx
#  424:	42                   	inc    edx
#  425:	43                   	inc    ebx
#  426:	5f                   	pop    edi
#  427:	32 2e                	xor    ch,BYTE PTR [esi]
#  429:	33 34 00             	xor    esi,DWORD PTR [eax+eax*1]
#  42c:	47                   	inc    edi
#  42d:	4c                   	dec    esp
#  42e:	49                   	dec    ecx
#  42f:	42                   	inc    edx
#  430:	43                   	inc    ebx
#  431:	5f                   	pop    edi
#  432:	32 2e                	xor    ch,BYTE PTR [esi]
#  434:	31 2e                	xor    DWORD PTR [esi],ebp
#  436:	33 00                	xor    eax,DWORD PTR [eax]
#
# Disassembly of section .gnu.version:
#
# 00000438 <.gnu.version>:
#  438:	00 00                	add    BYTE PTR [eax],al
#  43a:	02 00                	add    al,BYTE PTR [eax]
#  43c:	03 00                	add    eax,DWORD PTR [eax]
#  43e:	04 00                	add    al,0x0
#  440:	03 00                	add    eax,DWORD PTR [eax]
#  442:	03 00                	add    eax,DWORD PTR [eax]
#  444:	03 00                	add    eax,DWORD PTR [eax]
#  446:	05 00 01 00 01       	add    eax,0x1000100
#  44b:	00 01                	add    BYTE PTR [ecx],al
#  44d:	00 01                	add    BYTE PTR [ecx],al
# 	...
#
# Disassembly of section .gnu.version_r:
#
# 00000450 <.gnu.version_r>:
#  450:	01 00                	add    DWORD PTR [eax],eax
#  452:	02 00                	add    al,BYTE PTR [eax]
#  454:	21 01                	and    DWORD PTR [ecx],eax
#  456:	00 00                	add    BYTE PTR [eax],al
#  458:	10 00                	adc    BYTE PTR [eax],al
#  45a:	00 00                	add    BYTE PTR [eax],al
#  45c:	30 00                	xor    BYTE PTR [eax],al
#  45e:	00 00                	add    BYTE PTR [eax],al
#  460:	42                   	inc    edx
#  461:	f8                   	clc
#  462:	97                   	xchg   edi,eax
#  463:	02 00                	add    al,BYTE PTR [eax]
#  465:	00 05 00 3a 01 00    	add    BYTE PTR ds:0x13a00,al
#  46b:	00 10                	add    BYTE PTR [eax],dl
#  46d:	00 00                	add    BYTE PTR [eax],al
#  46f:	00 74 29 92          	add    BYTE PTR [ecx+ebp*1-0x6e],dh
#  473:	08 00                	or     BYTE PTR [eax],al
#  475:	00 03                	add    BYTE PTR [ebx],al
#  477:	00 49 01             	add    BYTE PTR [ecx+0x1],cl
#  47a:	00 00                	add    BYTE PTR [eax],al
#  47c:	00 00                	add    BYTE PTR [eax],al
#  47e:	00 00                	add    BYTE PTR [eax],al
#  480:	01 00                	add    DWORD PTR [eax],eax
#  482:	02 00                	add    al,BYTE PTR [eax]
#  484:	30 01                	xor    BYTE PTR [ecx],al
#  486:	00 00                	add    BYTE PTR [eax],al
#  488:	10 00                	adc    BYTE PTR [eax],al
#  48a:	00 00                	add    BYTE PTR [eax],al
#  48c:	00 00                	add    BYTE PTR [eax],al
#  48e:	00 00                	add    BYTE PTR [eax],al
#  490:	b4 91                	mov    ah,0x91
#  492:	96                   	xchg   esi,eax
#  493:	06                   	push   es
#  494:	00 00                	add    BYTE PTR [eax],al
#  496:	04 00                	add    al,0x0
#  498:	55                   	push   ebp
#  499:	01 00                	add    DWORD PTR [eax],eax
#  49b:	00 10                	add    BYTE PTR [eax],dl
#  49d:	00 00                	add    BYTE PTR [eax],al
#  49f:	00 73 1f             	add    BYTE PTR [ebx+0x1f],dh
#  4a2:	69 09 00 00 02 00    	imul   ecx,DWORD PTR [ecx],0x20000
#  4a8:	60                   	pusha
#  4a9:	01 00                	add    DWORD PTR [eax],eax
#  4ab:	00 00                	add    BYTE PTR [eax],al
#  4ad:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .rel.dyn:
#
# 000004b0 <.rel.dyn>:
#  4b0:	d8 3e                	fdivr  DWORD PTR [esi]
#  4b2:	00 00                	add    BYTE PTR [eax],al
#  4b4:	08 00                	or     BYTE PTR [eax],al
#  4b6:	00 00                	add    BYTE PTR [eax],al
#  4b8:	dc 3e                	fdivr  QWORD PTR [esi]
#  4ba:	00 00                	add    BYTE PTR [eax],al
#  4bc:	08 00                	or     BYTE PTR [eax],al
#  4be:	00 00                	add    BYTE PTR [eax],al
#  4c0:	dc 3f                	fdivr  QWORD PTR [edi]
#  4c2:	00 00                	add    BYTE PTR [eax],al
#  4c4:	08 00                	or     BYTE PTR [eax],al
#  4c6:	00 00                	add    BYTE PTR [eax],al
#  4c8:	10 40 00             	adc    BYTE PTR [eax+0x0],al
#  4cb:	00 08                	add    BYTE PTR [eax],cl
#  4cd:	00 00                	add    BYTE PTR [eax],al
#  4cf:	00 d8                	add    al,bl
#  4d1:	3f                   	aas
#  4d2:	00 00                	add    BYTE PTR [eax],al
#  4d4:	06                   	push   es
#  4d5:	01 00                	add    DWORD PTR [eax],eax
#  4d7:	00 e0                	add    al,ah
#  4d9:	3f                   	aas
#  4da:	00 00                	add    BYTE PTR [eax],al
#  4dc:	06                   	push   es
#  4dd:	02 00                	add    al,BYTE PTR [eax]
#  4df:	00 e4                	add    ah,ah
#  4e1:	3f                   	aas
#  4e2:	00 00                	add    BYTE PTR [eax],al
#  4e4:	06                   	push   es
#  4e5:	06                   	push   es
#  4e6:	00 00                	add    BYTE PTR [eax],al
#  4e8:	e8 3f 00 00 06       	call   600052c <_end+0x5ffc514>
#  4ed:	08 00                	or     BYTE PTR [eax],al
#  4ef:	00 ec                	add    ah,ch
#  4f1:	3f                   	aas
#  4f2:	00 00                	add    BYTE PTR [eax],al
#  4f4:	06                   	push   es
#  4f5:	09 00                	or     DWORD PTR [eax],eax
#  4f7:	00 f0                	add    al,dh
#  4f9:	3f                   	aas
#  4fa:	00 00                	add    BYTE PTR [eax],al
#  4fc:	06                   	push   es
#  4fd:	0a 00                	or     al,BYTE PTR [eax]
# 	...
#
# Disassembly of section .rel.plt:
#
# 00000500 <.rel.plt>:
#  500:	00 40 00             	add    BYTE PTR [eax+0x0],al
#  503:	00 07                	add    BYTE PTR [edi],al
#  505:	03 00                	add    eax,DWORD PTR [eax]
#  507:	00 04 40             	add    BYTE PTR [eax+eax*2],al
#  50a:	00 00                	add    BYTE PTR [eax],al
#  50c:	07                   	pop    es
#  50d:	04 00                	add    al,0x0
#  50f:	00 08                	add    BYTE PTR [eax],cl
#  511:	40                   	inc    eax
#  512:	00 00                	add    BYTE PTR [eax],al
#  514:	07                   	pop    es
#  515:	05                   	.byte 0x5
# 	...
#
# Disassembly of section .init:
#
# 00001000 <_init>:
#     1000:	53                   	push   ebx
#     1001:	83 ec 08             	sub    esp,0x8
#     1004:	e8 97 00 00 00       	call   10a0 <__x86.get_pc_thunk.bx>
#     1009:	81 c3 eb 2f 00 00    	add    ebx,0x2feb
#     100f:	8b 83 f8 ff ff ff    	mov    eax,DWORD PTR [ebx-0x8]
#     1015:	85 c0                	test   eax,eax
#     1017:	74 02                	je     101b <_init+0x1b>
#     1019:	ff d0                	call   eax
#     101b:	83 c4 08             	add    esp,0x8
#     101e:	5b                   	pop    ebx
#     101f:	c3                   	ret
#
# Disassembly of section .plt:
#
# 00001020 <__libc_start_main@plt-0x10>:
#     1020:	ff b3 04 00 00 00    	push   DWORD PTR [ebx+0x4]
#     1026:	ff a3 08 00 00 00    	jmp    DWORD PTR [ebx+0x8]
#     102c:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# 00001030 <__libc_start_main@plt>:
#     1030:	ff a3 0c 00 00 00    	jmp    DWORD PTR [ebx+0xc]
#     1036:	68 00 00 00 00       	push   0x0
#     103b:	e9 e0 ff ff ff       	jmp    1020 <_init+0x20>
#
# 00001040 <_ZStlsISt11char_traitsIcEERSt13basic_ostreamIcT_ES5_PKc@plt>:
#     1040:	ff a3 10 00 00 00    	jmp    DWORD PTR [ebx+0x10]
#     1046:	68 08 00 00 00       	push   0x8
#     104b:	e9 d0 ff ff ff       	jmp    1020 <_init+0x20>
#
# 00001050 <_ZNSolsEPFRSoS_E@plt>:
#     1050:	ff a3 14 00 00 00    	jmp    DWORD PTR [ebx+0x14]
#     1056:	68 10 00 00 00       	push   0x10
#     105b:	e9 c0 ff ff ff       	jmp    1020 <_init+0x20>
#
# Disassembly of section .plt.got:
#
# 00001060 <__cxa_finalize@plt>:
#     1060:	ff a3 e4 ff ff ff    	jmp    DWORD PTR [ebx-0x1c]
#     1066:	66 90                	xchg   ax,ax
#
# Disassembly of section .text:
#
# 00001070 <_start>:
#     1070:	31 ed                	xor    ebp,ebp
#     1072:	5e                   	pop    esi
#     1073:	89 e1                	mov    ecx,esp
#     1075:	83 e4 f0             	and    esp,0xfffffff0
#     1078:	50                   	push   eax
#     1079:	54                   	push   esp
#     107a:	52                   	push   edx
#     107b:	e8 18 00 00 00       	call   1098 <_start+0x28>
#     1080:	81 c3 74 2f 00 00    	add    ebx,0x2f74
#     1086:	6a 00                	push   0x0
#     1088:	6a 00                	push   0x0
#     108a:	51                   	push   ecx
#     108b:	56                   	push   esi
#     108c:	ff b3 e8 ff ff ff    	push   DWORD PTR [ebx-0x18]
#     1092:	e8 99 ff ff ff       	call   1030 <__libc_start_main@plt>
#     1097:	f4                   	hlt
#     1098:	8b 1c 24             	mov    ebx,DWORD PTR [esp]
#     109b:	c3                   	ret
#     109c:	66 90                	xchg   ax,ax
#     109e:	66 90                	xchg   ax,ax
#
# 000010a0 <__x86.get_pc_thunk.bx>:
#     10a0:	8b 1c 24             	mov    ebx,DWORD PTR [esp]
#     10a3:	c3                   	ret
#     10a4:	66 90                	xchg   ax,ax
#     10a6:	66 90                	xchg   ax,ax
#     10a8:	66 90                	xchg   ax,ax
#     10aa:	66 90                	xchg   ax,ax
#     10ac:	66 90                	xchg   ax,ax
#     10ae:	66 90                	xchg   ax,ax
#
# 000010b0 <deregister_tm_clones>:
#     10b0:	e8 e4 00 00 00       	call   1199 <__x86.get_pc_thunk.dx>
#     10b5:	81 c2 3f 2f 00 00    	add    edx,0x2f3f
#     10bb:	8d 8a 20 00 00 00    	lea    ecx,[edx+0x20]
#     10c1:	8d 82 20 00 00 00    	lea    eax,[edx+0x20]
#     10c7:	39 c8                	cmp    eax,ecx
#     10c9:	74 1d                	je     10e8 <deregister_tm_clones+0x38>
#     10cb:	8b 82 f4 ff ff ff    	mov    eax,DWORD PTR [edx-0xc]
#     10d1:	85 c0                	test   eax,eax
#     10d3:	74 13                	je     10e8 <deregister_tm_clones+0x38>
#     10d5:	55                   	push   ebp
#     10d6:	89 e5                	mov    ebp,esp
#     10d8:	83 ec 14             	sub    esp,0x14
#     10db:	51                   	push   ecx
#     10dc:	ff d0                	call   eax
#     10de:	83 c4 10             	add    esp,0x10
#     10e1:	c9                   	leave
#     10e2:	c3                   	ret
#     10e3:	2e 8d 74 26 00       	lea    esi,cs:[esi+eiz*1+0x0]
#     10e8:	c3                   	ret
#     10e9:	8d b4 26 00 00 00 00 	lea    esi,[esi+eiz*1+0x0]
#
# 000010f0 <register_tm_clones>:
#     10f0:	e8 a4 00 00 00       	call   1199 <__x86.get_pc_thunk.dx>
#     10f5:	81 c2 ff 2e 00 00    	add    edx,0x2eff
#     10fb:	55                   	push   ebp
#     10fc:	89 e5                	mov    ebp,esp
#     10fe:	53                   	push   ebx
#     10ff:	8d 8a 20 00 00 00    	lea    ecx,[edx+0x20]
#     1105:	8d 82 20 00 00 00    	lea    eax,[edx+0x20]
#     110b:	83 ec 04             	sub    esp,0x4
#     110e:	29 c8                	sub    eax,ecx
#     1110:	89 c3                	mov    ebx,eax
#     1112:	c1 e8 1f             	shr    eax,0x1f
#     1115:	c1 fb 02             	sar    ebx,0x2
#     1118:	01 d8                	add    eax,ebx
#     111a:	d1 f8                	sar    eax,1
#     111c:	74 14                	je     1132 <register_tm_clones+0x42>
#     111e:	8b 92 fc ff ff ff    	mov    edx,DWORD PTR [edx-0x4]
#     1124:	85 d2                	test   edx,edx
#     1126:	74 0a                	je     1132 <register_tm_clones+0x42>
#     1128:	83 ec 08             	sub    esp,0x8
#     112b:	50                   	push   eax
#     112c:	51                   	push   ecx
#     112d:	ff d2                	call   edx
#     112f:	83 c4 10             	add    esp,0x10
#     1132:	8b 5d fc             	mov    ebx,DWORD PTR [ebp-0x4]
#     1135:	c9                   	leave
#     1136:	c3                   	ret
#     1137:	2e 8d b4 26 00 00 00 	lea    esi,cs:[esi+eiz*1+0x0]
#     113e:	00
#     113f:	90                   	nop
#
# 00001140 <__do_global_dtors_aux>:
#     1140:	f3 0f 1e fb          	endbr32
#     1144:	55                   	push   ebp
#     1145:	89 e5                	mov    ebp,esp
#     1147:	53                   	push   ebx
#     1148:	e8 53 ff ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     114d:	81 c3 a7 2e 00 00    	add    ebx,0x2ea7
#     1153:	83 ec 04             	sub    esp,0x4
#     1156:	80 bb 20 00 00 00 00 	cmp    BYTE PTR [ebx+0x20],0x0
#     115d:	75 27                	jne    1186 <__do_global_dtors_aux+0x46>
#     115f:	8b 83 e4 ff ff ff    	mov    eax,DWORD PTR [ebx-0x1c]
#     1165:	85 c0                	test   eax,eax
#     1167:	74 11                	je     117a <__do_global_dtors_aux+0x3a>
#     1169:	83 ec 0c             	sub    esp,0xc
#     116c:	ff b3 1c 00 00 00    	push   DWORD PTR [ebx+0x1c]
#     1172:	e8 e9 fe ff ff       	call   1060 <__cxa_finalize@plt>
#     1177:	83 c4 10             	add    esp,0x10
#     117a:	e8 31 ff ff ff       	call   10b0 <deregister_tm_clones>
#     117f:	c6 83 20 00 00 00 01 	mov    BYTE PTR [ebx+0x20],0x1
#     1186:	8b 5d fc             	mov    ebx,DWORD PTR [ebp-0x4]
#     1189:	c9                   	leave
#     118a:	c3                   	ret
#     118b:	2e 8d 74 26 00       	lea    esi,cs:[esi+eiz*1+0x0]
#
# 00001190 <frame_dummy>:
#     1190:	f3 0f 1e fb          	endbr32
#     1194:	e9 57 ff ff ff       	jmp    10f0 <register_tm_clones>
#
# 00001199 <__x86.get_pc_thunk.dx>:
#     1199:	8b 14 24             	mov    edx,DWORD PTR [esp]
#     119c:	c3                   	ret
#
# 0000119d <main>:
#     119d:	8d 4c 24 04          	lea    ecx,[esp+0x4]
#     11a1:	83 e4 f0             	and    esp,0xfffffff0
#     11a4:	ff 71 fc             	push   DWORD PTR [ecx-0x4]
#     11a7:	55                   	push   ebp
#     11a8:	89 e5                	mov    ebp,esp
#     11aa:	53                   	push   ebx
#     11ab:	51                   	push   ecx
#     11ac:	e8 ef fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     11b1:	81 c3 43 2e 00 00    	add    ebx,0x2e43
#     11b7:	83 ec 08             	sub    esp,0x8
#     11ba:	8d 83 14 e0 ff ff    	lea    eax,[ebx-0x1fec]
#     11c0:	50                   	push   eax
#     11c1:	8b 83 f0 ff ff ff    	mov    eax,DWORD PTR [ebx-0x10]
#     11c7:	50                   	push   eax
#     11c8:	e8 73 fe ff ff       	call   1040 <_ZStlsISt11char_traitsIcEERSt13basic_ostreamIcT_ES5_PKc@plt>
#     11cd:	83 c4 10             	add    esp,0x10
#     11d0:	83 ec 08             	sub    esp,0x8
#     11d3:	8b 93 ec ff ff ff    	mov    edx,DWORD PTR [ebx-0x14]
#     11d9:	52                   	push   edx
#     11da:	50                   	push   eax
#     11db:	e8 70 fe ff ff       	call   1050 <_ZNSolsEPFRSoS_E@plt>
#     11e0:	83 c4 10             	add    esp,0x10
#     11e3:	b8 00 00 00 00       	mov    eax,0x0
#     11e8:	8d 65 f8             	lea    esp,[ebp-0x8]
#     11eb:	59                   	pop    ecx
#     11ec:	5b                   	pop    ebx
#     11ed:	5d                   	pop    ebp
#     11ee:	8d 61 fc             	lea    esp,[ecx-0x4]
#     11f1:	c3                   	ret
#
# Disassembly of section .fini:
#
# 000011f4 <_fini>:
#     11f4:	53                   	push   ebx
#     11f5:	83 ec 08             	sub    esp,0x8
#     11f8:	e8 a3 fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     11fd:	81 c3 f7 2d 00 00    	add    ebx,0x2df7
#     1203:	83 c4 08             	add    esp,0x8
#     1206:	5b                   	pop    ebx
#     1207:	c3                   	ret
#
# Disassembly of section .rodata:
#
# 00002000 <_fp_hw>:
#     2000:	03 00                	add    eax,DWORD PTR [eax]
# 	...
#
# 00002004 <_IO_stdin_used>:
#     2004:	01 00                	add    DWORD PTR [eax],eax
#     2006:	02 00                	add    al,BYTE PTR [eax]
#     2008:	48                   	dec    eax
#     2009:	65 6c                	gs ins BYTE PTR es:[edi],dx
#     200b:	6c                   	ins    BYTE PTR es:[edi],dx
#     200c:	6f                   	outs   dx,DWORD PTR ds:[esi]
#     200d:	20 57 6f             	and    BYTE PTR [edi+0x6f],dl
#     2010:	72 6c                	jb     207e <__GNU_EH_FRAME_HDR+0x66>
#     2012:	64 21 00             	and    DWORD PTR fs:[eax],eax
#
# 00002015 <_ZNSt8__detail30__integer_to_chars_is_unsignedIjEE>:
#     2015:	01                 	add    DWORD PTR [ecx],eax
#
# 00002016 <_ZNSt8__detail30__integer_to_chars_is_unsignedImEE>:
#     2016:	01                 	add    DWORD PTR [ecx],eax
#
# 00002017 <_ZNSt8__detail30__integer_to_chars_is_unsignedIyEE>:
#     2017:	01                   	.byte 0x1
#
# Disassembly of section .eh_frame_hdr:
#
# 00002018 <__GNU_EH_FRAME_HDR>:
#     2018:	01 1b                	add    DWORD PTR [ebx],ebx
#     201a:	03 3b                	add    edi,DWORD PTR [ebx]
#     201c:	28 00                	sub    BYTE PTR [eax],al
#     201e:	00 00                	add    BYTE PTR [eax],al
#     2020:	04 00                	add    al,0x0
#     2022:	00 00                	add    BYTE PTR [eax],al
#     2024:	08 f0                	or     al,dh
#     2026:	ff                   	(bad)
#     2027:	ff 70 00             	push   DWORD PTR [eax+0x0]
#     202a:	00 00                	add    BYTE PTR [eax],al
#     202c:	48                   	dec    eax
#     202d:	f0 ff                	lock (bad)
#     202f:	ff 94 00 00 00 58 f0 	call   DWORD PTR [eax+eax*1-0xfa80000]
#     2036:	ff                   	(bad)
#     2037:	ff 44 00 00          	inc    DWORD PTR [eax+eax*1+0x0]
#     203b:	00 85 f1 ff ff a8    	add    BYTE PTR [ebp-0x5700000f],al
#     2041:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .eh_frame:
#
# 00002044 <__FRAME_END__-0xb0>:
#     2044:	14 00                	adc    al,0x0
#     2046:	00 00                	add    BYTE PTR [eax],al
#     2048:	00 00                	add    BYTE PTR [eax],al
#     204a:	00 00                	add    BYTE PTR [eax],al
#     204c:	01 7a 52             	add    DWORD PTR [edx+0x52],edi
#     204f:	00 01                	add    BYTE PTR [ecx],al
#     2051:	7c 08                	jl     205b <__GNU_EH_FRAME_HDR+0x43>
#     2053:	01 1b                	add    DWORD PTR [ebx],ebx
#     2055:	0c 04                	or     al,0x4
#     2057:	04 88                	add    al,0x88
#     2059:	01 07                	add    DWORD PTR [edi],eax
#     205b:	08 10                	or     BYTE PTR [eax],dl
#     205d:	00 00                	add    BYTE PTR [eax],al
#     205f:	00 1c 00             	add    BYTE PTR [eax+eax*1],bl
#     2062:	00 00                	add    BYTE PTR [eax],al
#     2064:	0c f0                	or     al,0xf0
#     2066:	ff                   	(bad)
#     2067:	ff 2c 00             	jmp    FWORD PTR [eax+eax*1]
#     206a:	00 00                	add    BYTE PTR [eax],al
#     206c:	00 00                	add    BYTE PTR [eax],al
#     206e:	00 00                	add    BYTE PTR [eax],al
#     2070:	14 00                	adc    al,0x0
#     2072:	00 00                	add    BYTE PTR [eax],al
#     2074:	00 00                	add    BYTE PTR [eax],al
#     2076:	00 00                	add    BYTE PTR [eax],al
#     2078:	01 7a 52             	add    DWORD PTR [edx+0x52],edi
#     207b:	00 01                	add    BYTE PTR [ecx],al
#     207d:	7c 08                	jl     2087 <__GNU_EH_FRAME_HDR+0x6f>
#     207f:	01 1b                	add    DWORD PTR [ebx],ebx
#     2081:	0c 04                	or     al,0x4
#     2083:	04 88                	add    al,0x88
#     2085:	01 00                	add    DWORD PTR [eax],eax
#     2087:	00 20                	add    BYTE PTR [eax],ah
#     2089:	00 00                	add    BYTE PTR [eax],al
#     208b:	00 1c 00             	add    BYTE PTR [eax+eax*1],bl
#     208e:	00 00                	add    BYTE PTR [eax],al
#     2090:	90                   	nop
#     2091:	ef                   	out    dx,eax
#     2092:	ff                   	(bad)
#     2093:	ff 40 00             	inc    DWORD PTR [eax+0x0]
#     2096:	00 00                	add    BYTE PTR [eax],al
#     2098:	00 0e                	add    BYTE PTR [esi],cl
#     209a:	08 46 0e             	or     BYTE PTR [esi+0xe],al
#     209d:	0c 4a                	or     al,0x4a
#     209f:	0f 0b                	ud2
#     20a1:	74 04                	je     20a7 <__GNU_EH_FRAME_HDR+0x8f>
#     20a3:	78 00                	js     20a5 <__GNU_EH_FRAME_HDR+0x8d>
#     20a5:	3f                   	aas
#     20a6:	1a 3b                	sbb    bh,BYTE PTR [ebx]
#     20a8:	2a 32                	sub    dh,BYTE PTR [edx]
#     20aa:	24 22                	and    al,0x22
#     20ac:	10 00                	adc    BYTE PTR [eax],al
#     20ae:	00 00                	add    BYTE PTR [eax],al
#     20b0:	40                   	inc    eax
#     20b1:	00 00                	add    BYTE PTR [eax],al
#     20b3:	00 ac ef ff ff 08 00 	add    BYTE PTR [edi+ebp*8+0x8ffff],ch
#     20ba:	00 00                	add    BYTE PTR [eax],al
#     20bc:	00 00                	add    BYTE PTR [eax],al
#     20be:	00 00                	add    BYTE PTR [eax],al
#     20c0:	30 00                	xor    BYTE PTR [eax],al
#     20c2:	00 00                	add    BYTE PTR [eax],al
#     20c4:	54                   	push   esp
#     20c5:	00 00                	add    BYTE PTR [eax],al
#     20c7:	00 d5                	add    ch,dl
#     20c9:	f0 ff                	lock (bad)
#     20cb:	ff 55 00             	call   DWORD PTR [ebp+0x0]
#     20ce:	00 00                	add    BYTE PTR [eax],al
#     20d0:	00 44 0c 01          	add    BYTE PTR [esp+ecx*1+0x1],al
#     20d4:	00 49 10             	add    BYTE PTR [ecx+0x10],cl
#     20d7:	05 02 75 00 42       	add    eax,0x42007502
#     20dc:	0f 03 75 78          	lsl    esi,WORD PTR [ebp+0x78]
#     20e0:	06                   	push   es
#     20e1:	10 03                	adc    BYTE PTR [ebx],al
#     20e3:	02 75 7c             	add    dh,BYTE PTR [ebp+0x7c]
#     20e6:	02 40 c1             	add    al,BYTE PTR [eax-0x3f]
#     20e9:	0c 01                	or     al,0x1
#     20eb:	00 41 c3             	add    BYTE PTR [ecx-0x3d],al
#     20ee:	41                   	inc    ecx
#     20ef:	c5 43 0c             	lds    eax,FWORD PTR [ebx+0xc]
#     20f2:	04 04                	add    al,0x4
#
# 000020f4 <__FRAME_END__>:
#     20f4:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .init_array:
#
# 00003ed8 <__frame_dummy_init_array_entry>:
#     3ed8:	90                   	nop
#     3ed9:	11 00                	adc    DWORD PTR [eax],eax
# 	...
#
# Disassembly of section .fini_array:
#
# 00003edc <__do_global_dtors_aux_fini_array_entry>:
#     3edc:	40                   	inc    eax
#     3edd:	11 00                	adc    DWORD PTR [eax],eax
# 	...
#
# Disassembly of section .dynamic:
#
# 00003ee0 <_DYNAMIC>:
#     3ee0:	01 00                	add    DWORD PTR [eax],eax
#     3ee2:	00 00                	add    BYTE PTR [eax],al
#     3ee4:	21 01                	and    DWORD PTR [ecx],eax
#     3ee6:	00 00                	add    BYTE PTR [eax],al
#     3ee8:	01 00                	add    DWORD PTR [eax],eax
#     3eea:	00 00                	add    BYTE PTR [eax],al
#     3eec:	30 01                	xor    BYTE PTR [ecx],al
#     3eee:	00 00                	add    BYTE PTR [eax],al
#     3ef0:	0c 00                	or     al,0x0
#     3ef2:	00 00                	add    BYTE PTR [eax],al
#     3ef4:	00 10                	add    BYTE PTR [eax],dl
#     3ef6:	00 00                	add    BYTE PTR [eax],al
#     3ef8:	0d 00 00 00 f4       	or     eax,0xf4000000
#     3efd:	11 00                	adc    DWORD PTR [eax],eax
#     3eff:	00 19                	add    BYTE PTR [ecx],bl
#     3f01:	00 00                	add    BYTE PTR [eax],al
#     3f03:	00 d8                	add    al,bl
#     3f05:	3e 00 00             	add    BYTE PTR ds:[eax],al
#     3f08:	1b 00                	sbb    eax,DWORD PTR [eax]
#     3f0a:	00 00                	add    BYTE PTR [eax],al
#     3f0c:	04 00                	add    al,0x0
#     3f0e:	00 00                	add    BYTE PTR [eax],al
#     3f10:	1a 00                	sbb    al,BYTE PTR [eax]
#     3f12:	00 00                	add    BYTE PTR [eax],al
#     3f14:	dc 3e                	fdivr  QWORD PTR [esi]
#     3f16:	00 00                	add    BYTE PTR [eax],al
#     3f18:	1c 00                	sbb    al,0x0
#     3f1a:	00 00                	add    BYTE PTR [eax],al
#     3f1c:	04 00                	add    al,0x0
#     3f1e:	00 00                	add    BYTE PTR [eax],al
#     3f20:	f5                   	cmc
#     3f21:	fe                   	(bad)
#     3f22:	ff 6f ec             	jmp    FWORD PTR [edi-0x14]
#     3f25:	01 00                	add    DWORD PTR [eax],eax
#     3f27:	00 05 00 00 00 cc    	add    BYTE PTR ds:0xcc000000,al
#     3f2d:	02 00                	add    al,BYTE PTR [eax]
#     3f2f:	00 06                	add    BYTE PTR [esi],al
#     3f31:	00 00                	add    BYTE PTR [eax],al
#     3f33:	00 0c 02             	add    BYTE PTR [edx+eax*1],cl
#     3f36:	00 00                	add    BYTE PTR [eax],al
#     3f38:	0a 00                	or     al,BYTE PTR [eax]
#     3f3a:	00 00                	add    BYTE PTR [eax],al
#     3f3c:	6c                   	ins    BYTE PTR es:[edi],dx
#     3f3d:	01 00                	add    DWORD PTR [eax],eax
#     3f3f:	00 0b                	add    BYTE PTR [ebx],cl
#     3f41:	00 00                	add    BYTE PTR [eax],al
#     3f43:	00 10                	add    BYTE PTR [eax],dl
#     3f45:	00 00                	add    BYTE PTR [eax],al
#     3f47:	00 15 00 00 00 00    	add    BYTE PTR ds:0x0,dl
#     3f4d:	00 00                	add    BYTE PTR [eax],al
#     3f4f:	00 03                	add    BYTE PTR [ebx],al
#     3f51:	00 00                	add    BYTE PTR [eax],al
#     3f53:	00 f4                	add    ah,dh
#     3f55:	3f                   	aas
#     3f56:	00 00                	add    BYTE PTR [eax],al
#     3f58:	02 00                	add    al,BYTE PTR [eax]
#     3f5a:	00 00                	add    BYTE PTR [eax],al
#     3f5c:	18 00                	sbb    BYTE PTR [eax],al
#     3f5e:	00 00                	add    BYTE PTR [eax],al
#     3f60:	14 00                	adc    al,0x0
#     3f62:	00 00                	add    BYTE PTR [eax],al
#     3f64:	11 00                	adc    DWORD PTR [eax],eax
#     3f66:	00 00                	add    BYTE PTR [eax],al
#     3f68:	17                   	pop    ss
#     3f69:	00 00                	add    BYTE PTR [eax],al
#     3f6b:	00 00                	add    BYTE PTR [eax],al
#     3f6d:	05 00 00 11 00       	add    eax,0x110000
#     3f72:	00 00                	add    BYTE PTR [eax],al
#     3f74:	b0 04                	mov    al,0x4
#     3f76:	00 00                	add    BYTE PTR [eax],al
#     3f78:	12 00                	adc    al,BYTE PTR [eax]
#     3f7a:	00 00                	add    BYTE PTR [eax],al
#     3f7c:	50                   	push   eax
#     3f7d:	00 00                	add    BYTE PTR [eax],al
#     3f7f:	00 13                	add    BYTE PTR [ebx],dl
#     3f81:	00 00                	add    BYTE PTR [eax],al
#     3f83:	00 08                	add    BYTE PTR [eax],cl
#     3f85:	00 00                	add    BYTE PTR [eax],al
#     3f87:	00 fb                	add    bl,bh
#     3f89:	ff                   	(bad)
#     3f8a:	ff 6f 00             	jmp    FWORD PTR [edi+0x0]
#     3f8d:	00 00                	add    BYTE PTR [eax],al
#     3f8f:	08 fe                	or     dh,bh
#     3f91:	ff                   	(bad)
#     3f92:	ff 6f 50             	jmp    FWORD PTR [edi+0x50]
#     3f95:	04 00                	add    al,0x0
#     3f97:	00 ff                	add    bh,bh
#     3f99:	ff                   	(bad)
#     3f9a:	ff 6f 02             	jmp    FWORD PTR [edi+0x2]
#     3f9d:	00 00                	add    BYTE PTR [eax],al
#     3f9f:	00 f0                	add    al,dh
#     3fa1:	ff                   	(bad)
#     3fa2:	ff 6f 38             	jmp    FWORD PTR [edi+0x38]
#     3fa5:	04 00                	add    al,0x0
#     3fa7:	00 fa                	add    dl,bh
#     3fa9:	ff                   	(bad)
#     3faa:	ff 6f 04             	jmp    FWORD PTR [edi+0x4]
# 	...
#
# Disassembly of section .got:
#
# 00003fd8 <.got>:
#     3fd8:	00 00                	add    BYTE PTR [eax],al
#     3fda:	00 00                	add    BYTE PTR [eax],al
#     3fdc:	9d                   	popf
#     3fdd:	11 00                	adc    DWORD PTR [eax],eax
# 	...
#
# Disassembly of section .got.plt:
#
# 00003ff4 <_GLOBAL_OFFSET_TABLE_>:
#     3ff4:	e0 3e                	loopne 4034 <_end+0x1c>
# 	...
#     3ffe:	00 00                	add    BYTE PTR [eax],al
#     4000:	36 10 00             	adc    BYTE PTR ss:[eax],al
#     4003:	00 46 10             	add    BYTE PTR [esi+0x10],al
#     4006:	00 00                	add    BYTE PTR [eax],al
#     4008:	56                   	push   esi
#     4009:	10 00                	adc    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .data:
#
# 0000400c <__data_start>:
#     400c:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# 00004010 <__dso_handle>:
#     4010:	10 40 00             	adc    BYTE PTR [eax+0x0],al
# 	...
#
# Disassembly of section .comment:
#
# 00000000 <.comment>:
#    0:	47                   	inc    edi
#    1:	43                   	inc    ebx
#    2:	43                   	inc    ebx
#    3:	3a 20                	cmp    ah,BYTE PTR [eax]
#    5:	28 44 65 62          	sub    BYTE PTR [ebp+eiz*2+0x62],al
#    9:	69 61 6e 20 31 33 2e 	imul   esp,DWORD PTR [ecx+0x6e],0x2e333120
#   10:	32 2e                	xor    ch,BYTE PTR [esi]
#   12:	30 2d 32 33 29 20    	xor    BYTE PTR ds:0x20293332,ch
#   18:	31 33                	xor    DWORD PTR [ebx],esi
#   1a:	2e 32 2e             	xor    ch,BYTE PTR cs:[esi]
#   1d:	30 00                	xor    BYTE PTR [eax],al

# %%
! objdump -M intel -D hello.exe | grep -A20 main.:
# Out:
# 0000119d <main>:
#     119d:	8d 4c 24 04          	lea    ecx,[esp+0x4]
#     11a1:	83 e4 f0             	and    esp,0xfffffff0
#     11a4:	ff 71 fc             	push   DWORD PTR [ecx-0x4]
#     11a7:	55                   	push   ebp
#     11a8:	89 e5                	mov    ebp,esp
#     11aa:	53                   	push   ebx
#     11ab:	51                   	push   ecx
#     11ac:	e8 ef fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     11b1:	81 c3 43 2e 00 00    	add    ebx,0x2e43
#     11b7:	83 ec 08             	sub    esp,0x8
#     11ba:	8d 83 14 e0 ff ff    	lea    eax,[ebx-0x1fec]
#     11c0:	50                   	push   eax
#     11c1:	8b 83 f0 ff ff ff    	mov    eax,DWORD PTR [ebx-0x10]
#     11c7:	50                   	push   eax
#     11c8:	e8 73 fe ff ff       	call   1040 <_ZStlsISt11char_traitsIcEERSt13basic_ostreamIcT_ES5_PKc@plt>
#     11cd:	83 c4 10             	add    esp,0x10
#     11d0:	83 ec 08             	sub    esp,0x8
#     11d3:	8b 93 ec ff ff ff    	mov    edx,DWORD PTR [ebx-0x14]
#     11d9:	52                   	push   edx
#     11da:	50                   	push   eax

# %% [markdown]
# ## Hex Editor
# - hex editor is used modify binary and its contents
# - Google online hexeditor better than CLI hexeditor provided by Kali
#     - https://hexed.it/ is pretty good one!
# - compile and edit demos/system.cpp program to spawn a shell
# - search and replace "clear" with "73 68 00 00 00" (sh)

# %%
! g++ -o program.exe ../demos/system.cpp

# %%
! cat ../demos/system.cpp
# Out:
# #include <iostream>
# #include <cstdlib>
#
# using namespace std;
#
# int main() {
#     cout << "Hello World!\n";
#     system("clear");
#     cout << "good bye!" << endl;
#     return 0;
# }

# %%
! ./program.exe
# run the program from terminal for better demo
# Out:
# Hello World!
# good bye!
