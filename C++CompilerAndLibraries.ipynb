# %% [markdown]
# # Compiler and Libraries required
#
# - update the system
# - g++ compiler
# - multilib library to compile x86 programs in x64-bit OS

# %%
# update the system
! echo kali | sudo -S apt update -y
# Out:
# Hit:1 http://dl.google.com/linux/chrome/deb stable InRelease
# Hit:2 https://packages.microsoft.com/repos/vscode stable InRelease
# Hit:3 http://kali.download/kali kali-rolling InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 948 packages can be upgraded. Run 'apt list --upgradable' to see them.

# %%
# install g++ compiler
! echo kali | sudo -S apt install build-essential
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.8).
# The following packages were automatically installed and are no longer required:
#   libcdio18 libmpdec2 libprotobuf22 libx264-155 libx264-159
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
# install multilib library for gcc and g++
# -y automatically answers Y if asked
! echo kali | sudo -S apt install -y gcc-multilib g++-multilib
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libcdio18 libmpdec2 libprotobuf22 libx264-155 libx264-159
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu cpp cpp-10 g++ g++-10
#   g++-10-multilib gcc gcc-10 gcc-10-base gcc-10-multilib lib32asan6
#   lib32atomic1 lib32gcc-10-dev lib32gcc-s1 lib32gomp1 lib32itm1 lib32quadmath0
#   lib32stdc++-10-dev lib32stdc++6 lib32ubsan1 libasan6 libatomic1 libbinutils
#   libcc1-0 libctf0 libgc1 libgcc-10-dev libgcc-s1 libgfortran5 libgomp1
#   libitm1 liblsan0 libobjc4 libquadmath0 libstdc++-10-dev libstdc++6 libtsan0
#   libubsan1 libx32asan6 libx32atomic1 libx32gcc-10-dev libx32gcc-s1
#   libx32gomp1 libx32itm1 libx32quadmath0 libx32stdc++-10-dev libx32stdc++6
#   libx32ubsan1
# Suggested packages:
#   binutils-doc cpp-doc gcc-10-locales gcc-10-doc lib32stdc++6-10-dbg
#   libx32stdc++6-10-dbg manpages-dev autoconf automake libtool flex bison
#   gcc-doc libstdc++-10-doc
# The following packages will be REMOVED:
#   libgc1c2
# The following NEW packages will be installed:
#   cpp-10 g++-10 g++-10-multilib g++-multilib gcc-10 gcc-10-multilib lib32asan6
#   lib32gcc-10-dev lib32stdc++-10-dev libasan6 libgc1 libgcc-10-dev
#   libstdc++-10-dev libx32asan6 libx32gcc-10-dev libx32stdc++-10-dev
# The following packages will be upgraded:
#   binutils binutils-common binutils-x86-64-linux-gnu cpp g++ gcc gcc-10-base
#   gcc-multilib lib32atomic1 lib32gcc-s1 lib32gomp1 lib32itm1 lib32quadmath0
#   lib32stdc++6 lib32ubsan1 libatomic1 libbinutils libcc1-0 libctf0 libgcc-s1
#   libgfortran5 libgomp1 libitm1 liblsan0 libobjc4 libquadmath0 libstdc++6
#   libtsan0 libubsan1 libx32atomic1 libx32gcc-s1 libx32gomp1 libx32itm1
#   libx32quadmath0 libx32stdc++6 libx32ubsan1
# 36 upgraded, 16 newly installed, 1 to remove and 912 not upgraded.
# Need to get 223 MB of archives.
# After this operation, 1,066 MB of additional disk space will be used.
# Get:1 http://kali.download/kali kali-rolling/main amd64 lib32atomic1 amd64 10.2.0-16 [8,508 B]
# Get:2 http://kali.download/kali kali-rolling/main amd64 libx32gcc-s1 amd64 10.2.0-16 [41.3 kB]
# Get:3 http://kali.download/kali kali-rolling/main amd64 libx32stdc++6 amd64 10.2.0-16 [476 kB]
# Get:4 http://kali.download/kali kali-rolling/main amd64 libx32ubsan1 amd64 10.2.0-16 [134 kB]
# Get:5 http://kali.download/kali kali-rolling/main amd64 libx32quadmath0 amd64 10.2.0-16 [148 kB]
# Get:6 http://kali.download/kali kali-rolling/main amd64 libx32itm1 amd64 10.2.0-16 [26.1 kB]
# Get:7 http://kali.download/kali kali-rolling/main amd64 libx32gomp1 amd64 10.2.0-16 [102 kB]
# Get:8 http://kali.download/kali kali-rolling/main amd64 libx32atomic1 amd64 10.2.0-16 [8,972 B]
# Get:9 http://kali.download/kali kali-rolling/main amd64 libubsan1 amd64 10.2.0-16 [134 kB]
# Get:10 http://kali.download/kali kali-rolling/main amd64 libtsan0 amd64 10.2.0-16 [313 kB]
# Get:11 http://kali.download/kali kali-rolling/main amd64 gcc-10-base amd64 10.2.0-16 [200 kB]
# Get:12 http://kali.download/kali kali-rolling/main amd64 libstdc++6 amd64 10.2.0-16 [493 kB]
# Get:13 http://kali.download/kali kali-rolling/main amd64 libquadmath0 amd64 10.2.0-16 [145 kB]
# Get:14 http://kali.download/kali kali-rolling/main amd64 libgc1 amd64 1:8.0.4-2.1 [239 kB]
# Get:15 http://kali.download/kali kali-rolling/main amd64 libobjc4 amd64 10.2.0-16 [41.6 kB]
# Get:16 http://kali.download/kali kali-rolling/main amd64 liblsan0 amd64 10.2.0-16 [141 kB]
# Get:17 http://kali.download/kali kali-rolling/main amd64 libitm1 amd64 10.2.0-16 [25.8 kB]
# Get:18 http://kali.download/kali kali-rolling/main amd64 libgomp1 amd64 10.2.0-16 [99.9 kB]
# Get:19 http://kali.download/kali kali-rolling/main amd64 libgfortran5 amd64 10.2.0-16 [727 kB]
# Get:20 http://kali.download/kali kali-rolling/main amd64 libcc1-0 amd64 10.2.0-16 [39.7 kB]
# Get:21 http://kali.download/kali kali-rolling/main amd64 libatomic1 amd64 10.2.0-16 [9,004 B]
# Get:22 http://kali.download/kali kali-rolling/main amd64 lib32ubsan1 amd64 10.2.0-16 [151 kB]
# Get:23 http://kali.download/kali kali-rolling/main amd64 lib32gcc-s1 amd64 10.2.0-16 [49.4 kB]
# Get:24 http://kali.download/kali kali-rolling/main amd64 lib32stdc++6 amd64 10.2.0-16 [510 kB]
# Get:25 http://kali.download/kali kali-rolling/main amd64 lib32quadmath0 amd64 10.2.0-16 [229 kB]
# Get:26 http://kali.download/kali kali-rolling/main amd64 lib32itm1 amd64 10.2.0-16 [27.8 kB]
# Get:27 http://kali.download/kali kali-rolling/main amd64 lib32gomp1 amd64 10.2.0-16 [107 kB]
# Get:28 http://kali.download/kali kali-rolling/main amd64 libgcc-s1 amd64 10.2.0-16 [41.4 kB]
# Get:29 http://kali.download/kali kali-rolling/main amd64 libctf0 amd64 2.35.1-3 [46.4 kB]
# Get:30 http://kali.download/kali kali-rolling/main amd64 binutils-x86-64-linux-gnu amd64 2.35.1-3 [1,623 kB]
# Get:31 http://kali.download/kali kali-rolling/main amd64 libbinutils amd64 2.35.1-3 [475 kB]33m
# Get:32 http://kali.download/kali kali-rolling/main amd64 binutils amd64 2.35.1-3 [60.2 kB]
# Get:33 http://kali.download/kali kali-rolling/main amd64 binutils-common amd64 2.35.1-3 [2,217 kB]
# Get:34 http://kali.download/kali kali-rolling/main amd64 cpp-10 amd64 10.2.0-16 [62.8 MB]
# Get:35 http://kali.download/kali kali-rolling/main amd64 libasan6 amd64 10.2.0-16 [340 kB]
# Get:36 http://kali.download/kali kali-rolling/main amd64 libgcc-10-dev amd64 10.2.0-16 [2,328 kB]
# Get:37 http://kali.download/kali kali-rolling/main amd64 gcc-10 amd64 10.2.0-16 [70.9 MB]
# Get:38 http://kali.download/kali kali-rolling/main amd64 lib32asan6 amd64 10.2.0-16 [347 kB]m
# Get:39 http://kali.download/kali kali-rolling/main amd64 libx32asan6 amd64 10.2.0-16 [322 kB]
# Get:40 http://kali.download/kali kali-rolling/main amd64 lib32gcc-10-dev amd64 10.2.0-16 [2,181 kB]
# Get:41 http://kali.download/kali kali-rolling/main amd64 libx32gcc-10-dev amd64 10.2.0-16 [1,967 kB]
# Get:42 http://kali.download/kali kali-rolling/main amd64 gcc-10-multilib amd64 10.2.0-16 [1,020 B]
# Get:43 http://kali.download/kali kali-rolling/main amd64 gcc-multilib amd64 4:10.2.0-1 [1,492 B]
# Get:44 http://kali.download/kali kali-rolling/main amd64 g++ amd64 4:10.2.0-1 [1,644 B]m
# Get:45 http://kali.download/kali kali-rolling/main amd64 gcc amd64 4:10.2.0-1 [5,196 B]m
# Get:46 http://kali.download/kali kali-rolling/main amd64 libstdc++-10-dev amd64 10.2.0-16 [1,738 kB]
# Get:47 http://kali.download/kali kali-rolling/main amd64 g++-10 amd64 10.2.0-16 [69.1 MB]
# Get:48 http://kali.download/kali kali-rolling/main amd64 cpp amd64 4:10.2.0-1 [19.7 kB]m
# Get:49 http://kali.download/kali kali-rolling/main amd64 lib32stdc++-10-dev amd64 10.2.0-16 [737 kB]
# Get:50 http://kali.download/kali kali-rolling/main amd64 libx32stdc++-10-dev amd64 10.2.0-16 [686 kB]
# Get:51 http://kali.download/kali kali-rolling/main amd64 g++-10-multilib amd64 10.2.0-16 [1,028 B]
# Get:52 http://kali.download/kali kali-rolling/main amd64 g++-multilib amd64 4:10.2.0-1 [996 B]
# Fetched 223 MB in 28s (7,914 kB/s)
# Extracting templates from packages: 100%
#
# (Reading database ... 262311 files and directories currently installed.)
# Preparing to unpack .../00-lib32atomic1_10.2.0-16_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking lib32atomic1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../01-libx32gcc-s1_10.2.0-16_amd64.deb ...
# 7Progress: [  1%] [..........................................................] 8Unpacking libx32gcc-s1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../02-libx32stdc++6_10.2.0-16_amd64.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking libx32stdc++6 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../03-libx32ubsan1_10.2.0-16_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libx32ubsan1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../04-libx32quadmath0_10.2.0-16_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libx32quadmath0 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../05-libx32itm1_10.2.0-16_amd64.deb ...
# 7Progress: [  5%] [###.......................................................] 8Unpacking libx32itm1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../06-libx32gomp1_10.2.0-16_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libx32gomp1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../07-libx32atomic1_10.2.0-16_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking libx32atomic1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../08-libubsan1_10.2.0-16_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libubsan1:amd64 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../09-libtsan0_10.2.0-16_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking libtsan0:amd64 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../10-gcc-10-base_10.2.0-16_amd64.deb ...
# Unpacking gcc-10-base:amd64 (10.2.0-16) over (10.1.0-6) ...
# 7Progress: [ 10%] [######....................................................] 8Setting up gcc-10-base:amd64 (10.2.0-16) ...
# (Reading database ... 262311 files and directories currently installed.).................................] 8(Reading database ...
# Preparing to unpack .../libstdc++6_10.2.0-16_amd64.deb ...
# Unpacking libstdc++6:amd64 (10.2.0-16) over (10.1.0-6) ...
# 7Progress: [ 12%] [#######...................................................] 8Setting up libstdc++6:amd64 (10.2.0-16) ...
# (Reading database ... 262311 files and directories currently installed.).................................] 8(Reading database ...
# Preparing to unpack .../libquadmath0_10.2.0-16_amd64.deb ...
# Unpacking libquadmath0:amd64 (10.2.0-16) over (10.1.0-6) ...
# 7Progress: [ 14%] [########..................................................] 8dpkg: libgc1c2:amd64: dependency problems, but removing anyway as you requested:
#  libobjc4:amd64 depends on libgc1c2 (>= 1:7.2d); however:
#   Package libgc1c2:amd64 is to be removed.
#
# (Reading database ... 262311 files and directories currently installed.)
# Removing libgc1c2:amd64 (1:7.6.4-0.4) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libgc1:amd64.
# (Reading database ... 262302 files and directories currently installed.)
# Preparing to unpack .../00-libgc1_1%3a8.0.4-2.1_amd64.deb ...
# Unpacking libgc1:amd64 (1:8.0.4-2.1) ...
# 7Progress: [ 16%] [#########.................................................] 8Preparing to unpack .../01-libobjc4_10.2.0-16_amd64.deb ...
# Unpacking libobjc4:amd64 (10.2.0-16) over (10.1.0-6) ...
# 7Progress: [ 17%] [#########.................................................] 8Preparing to unpack .../02-liblsan0_10.2.0-16_amd64.deb ...
# Unpacking liblsan0:amd64 (10.2.0-16) over (10.1.0-6) ...
# 7Progress: [ 18%] [##########................................................] 8Preparing to unpack .../03-libitm1_10.2.0-16_amd64.deb ...
# Unpacking libitm1:amd64 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../04-libgomp1_10.2.0-16_amd64.deb ...
# 7Progress: [ 19%] [###########...............................................] 8Unpacking libgomp1:amd64 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../05-libgfortran5_10.2.0-16_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libgfortran5:amd64 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../06-libcc1-0_10.2.0-16_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libcc1-0:amd64 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../07-libatomic1_10.2.0-16_amd64.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libatomic1:amd64 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../08-lib32ubsan1_10.2.0-16_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking lib32ubsan1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../09-lib32gcc-s1_10.2.0-16_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking lib32gcc-s1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../10-lib32stdc++6_10.2.0-16_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking lib32stdc++6 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../11-lib32quadmath0_10.2.0-16_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking lib32quadmath0 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../12-lib32itm1_10.2.0-16_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking lib32itm1 (10.2.0-16) over (10.1.0-6) ...
# Preparing to unpack .../13-lib32gomp1_10.2.0-16_amd64.deb ...
# Unpacking lib32gomp1 (10.2.0-16) over (10.1.0-6) ...
# 7Progress: [ 28%] [################..........................................] 8Preparing to unpack .../14-libgcc-s1_10.2.0-16_amd64.deb ...
# Unpacking libgcc-s1:amd64 (10.2.0-16) over (10.1.0-6) ...
# 7Progress: [ 29%] [#################.........................................] 8Setting up libgcc-s1:amd64 (10.2.0-16) ...
# (Reading database ... 262311 files and directories currently installed.).................................] 8(Reading database ...
# Preparing to unpack .../00-libctf0_2.35.1-3_amd64.deb ...
# Unpacking libctf0:amd64 (2.35.1-3) over (2.35-1) ...
# 7Progress: [ 31%] [##################........................................] 8Preparing to unpack .../01-binutils-x86-64-linux-gnu_2.35.1-3_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.35.1-3) over (2.35-1) ...
# 7Progress: [ 32%] [##################........................................] 8Preparing to unpack .../02-libbinutils_2.35.1-3_amd64.deb ...
# Unpacking libbinutils:amd64 (2.35.1-3) over (2.35-1) ...
# 7Progress: [ 33%] [###################.......................................] 8Preparing to unpack .../03-binutils_2.35.1-3_amd64.deb ...
# Unpacking binutils (2.35.1-3) over (2.35-1) ...
# 7Progress: [ 34%] [###################.......................................] 8Preparing to unpack .../04-binutils-common_2.35.1-3_amd64.deb ...
# Unpacking binutils-common:amd64 (2.35.1-3) over (2.35-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package cpp-10.
# Preparing to unpack .../05-cpp-10_10.2.0-16_amd64.deb ...
# Unpacking cpp-10 (10.2.0-16) ...
# 7Progress: [ 36%] [####################......................................] 8Selecting previously unselected package libasan6:amd64.
# Preparing to unpack .../06-libasan6_10.2.0-16_amd64.deb ...
# Unpacking libasan6:amd64 (10.2.0-16) ...
# Selecting previously unselected package libgcc-10-dev:amd64.
# Preparing to unpack .../07-libgcc-10-dev_10.2.0-16_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libgcc-10-dev:amd64 (10.2.0-16) ...
# Selecting previously unselected package gcc-10.
# Preparing to unpack .../08-gcc-10_10.2.0-16_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking gcc-10 (10.2.0-16) ...
# Selecting previously unselected package lib32asan6.
# Preparing to unpack .../09-lib32asan6_10.2.0-16_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking lib32asan6 (10.2.0-16) ...
# Selecting previously unselected package libx32asan6.
# Preparing to unpack .../10-libx32asan6_10.2.0-16_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libx32asan6 (10.2.0-16) ...
# Selecting previously unselected package lib32gcc-10-dev.
# Preparing to unpack .../11-lib32gcc-10-dev_10.2.0-16_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking lib32gcc-10-dev (10.2.0-16) ...
# Selecting previously unselected package libx32gcc-10-dev.
# Preparing to unpack .../12-libx32gcc-10-dev_10.2.0-16_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libx32gcc-10-dev (10.2.0-16) ...
# Selecting previously unselected package gcc-10-multilib.
# Preparing to unpack .../13-gcc-10-multilib_10.2.0-16_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking gcc-10-multilib (10.2.0-16) ...
# Preparing to unpack .../14-gcc-multilib_4%3a10.2.0-1_amd64.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking gcc-multilib (4:10.2.0-1) over (4:9.2.1-3.1) ...
# Preparing to unpack .../15-g++_4%3a10.2.0-1_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking g++ (4:10.2.0-1) over (4:9.2.1-3.1) ...
# Preparing to unpack .../16-gcc_4%3a10.2.0-1_amd64.deb ...
# Unpacking gcc (4:10.2.0-1) over (4:9.2.1-3.1) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libstdc++-10-dev:amd64.
# Preparing to unpack .../17-libstdc++-10-dev_10.2.0-16_amd64.deb ...
# Unpacking libstdc++-10-dev:amd64 (10.2.0-16) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package g++-10.
# Preparing to unpack .../18-g++-10_10.2.0-16_amd64.deb ...
# Unpacking g++-10 (10.2.0-16) ...
# 7Progress: [ 48%] [############################..............................] 8Preparing to unpack .../19-cpp_4%3a10.2.0-1_amd64.deb ...
# Unpacking cpp (4:10.2.0-1) over (4:9.2.1-3.1) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package lib32stdc++-10-dev.
# Preparing to unpack .../20-lib32stdc++-10-dev_10.2.0-16_amd64.deb ...
# Unpacking lib32stdc++-10-dev (10.2.0-16) ...
# 7Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package libx32stdc++-10-dev.
# Preparing to unpack .../21-libx32stdc++-10-dev_10.2.0-16_amd64.deb ...
# Unpacking libx32stdc++-10-dev (10.2.0-16) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package g++-10-multilib.
# Preparing to unpack .../22-g++-10-multilib_10.2.0-16_amd64.deb ...
# Unpacking g++-10-multilib (10.2.0-16) ...
# 7Progress: [ 52%] [##############################............................] 8Selecting previously unselected package g++-multilib.
# Preparing to unpack .../23-g++-multilib_4%3a10.2.0-1_amd64.deb ...
# Unpacking g++-multilib (4:10.2.0-1) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up lib32itm1 (10.2.0-16) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libx32gcc-s1 (10.2.0-16) ...
# Setting up binutils-common:amd64 (2.35.1-3) ...
# 7Progress: [ 55%] [################################..........................] 8Setting up libx32itm1 (10.2.0-16) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libgomp1:amd64 (10.2.0-16) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libasan6:amd64 (10.2.0-16) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up lib32gomp1 (10.2.0-16) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libx32asan6 (10.2.0-16) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up lib32gcc-s1 (10.2.0-16) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up lib32stdc++6 (10.2.0-16) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libquadmath0:amd64 (10.2.0-16) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libatomic1:amd64 (10.2.0-16) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libx32gomp1 (10.2.0-16) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libgc1:amd64 (1:8.0.4-2.1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libgfortran5:amd64 (10.2.0-16) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up lib32asan6 (10.2.0-16) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libubsan1:amd64 (10.2.0-16) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up lib32quadmath0 (10.2.0-16) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libx32quadmath0 (10.2.0-16) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libbinutils:amd64 (2.35.1-3) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up lib32atomic1 (10.2.0-16) ...
# Setting up libcc1-0:amd64 (10.2.0-16) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up liblsan0:amd64 (10.2.0-16) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up cpp-10 (10.2.0-16) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libitm1:amd64 (10.2.0-16) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libtsan0:amd64 (10.2.0-16) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libx32stdc++6 (10.2.0-16) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libx32atomic1 (10.2.0-16) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libctf0:amd64 (2.35.1-3) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libx32ubsan1 (10.2.0-16) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libgcc-10-dev:amd64 (10.2.0-16) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libobjc4:amd64 (10.2.0-16) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up lib32ubsan1 (10.2.0-16) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up lib32gcc-10-dev (10.2.0-16) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up cpp (4:10.2.0-1) ...
# 7Progress: [ 86%] [##################################################........] 8Setting up binutils-x86-64-linux-gnu (2.35.1-3) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libstdc++-10-dev:amd64 (10.2.0-16) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libx32gcc-10-dev (10.2.0-16) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libx32stdc++-10-dev (10.2.0-16) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up binutils (2.35.1-3) ...
# Setting up gcc-10 (10.2.0-16) ...
# 7Progress: [ 91%] [#####################################################.....] 8Setting up lib32stdc++-10-dev (10.2.0-16) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up g++-10 (10.2.0-16) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up gcc (4:10.2.0-1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up gcc-10-multilib (10.2.0-16) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up g++ (4:10.2.0-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up g++-10-multilib (10.2.0-16) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up gcc-multilib (4:10.2.0-1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up g++-multilib (4:10.2.0-1) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for kali-menu (2020.3.2) ...
# Processing triggers for libc-bin (2.31-2) ...
# Processing triggers for ccache (3.7.11-1) ...
# Updating symlinks in /usr/lib/ccache ...
# Processing triggers for man-db (2.9.3-2) ...
#
# 78

# %%
Y
